# %%
address_structure = {
    "type": "FeatureCollection",
    "name": "address",
    "features": [
        {
            "geometry": None,
            "feature_type":"address",
            "id": "",
            "properties": {
                "address": "CPC4, Capital Park, Fulbourn, Cambridge",
                "country": "GB",
                "locality": "Cambridge",
                "postal_code": "CB21 5XE",
                "postal_code_ext": None,
                "province": "GB-CAM",
                "unit": None
            },
            "type": "Feature"
        }
    ]
}

amenity_structure = {
    "type": "FeatureCollection",
   "name": "amenity",
    "features": [
        {
            "geometry": {
                "type": "Point",
                "coordinates": []
            },
            "type": "Feature",
            "feature_type":"amenity",
            "id": "",
            "properties": {
                "accessibility": None,
                "address_id": "",
                "alt_name": None,
                "category": "restroom",
                "correlation_id": None,
                "hours": None,
                "name": None,
                "phone": None,
                "unit_ids": [],
                "website": None
            }
        }
    ]
}

anchor_structure = {
    "type": "FeatureCollection",
   "name": "anchor",
    "features": [
        {
            "geometry": {
                "type": "Point",
                "coordinates": []
            },
            "feature_type":"anchor",
            "id": "",
            "properties": {
                "address_id": "",
                "unit_id": ""
            },
            "type": "Feature"
        }
    ]
}

building_structure = {
    "type": "FeatureCollection",
   "name": "building",
        "features": [
        {
            "geometry": None,
            "feature_type":"building",
            "id": "",
            "properties": {
                "address_id": "",
                "alt_name": None,
                "category": "unspecified",
                "display_point": {
                    "coordinates": [0.19458723822821,
          52.185771666941406],
                    "type":"Point"
                },
                "name": {
                    "en": "CPC4"
                },
                "restriction": None
            },
            "type": "Feature"
        }
    ]
}

footprint_structure = {
    "type": "FeatureCollection",
    "name": "footprint",
     "features": [
        {
            "geometry": {
                "type": "MultiPolygon",
                "coordinates": []
            },
            "feature_type":"footprint",
            "id": "",
            "properties": {
                "building_ids": [],
                "category": "ground",
                "name": None
            },
            "type": "Feature"
        }
    ]
}

level_structure = {
    "type": "FeatureCollection",
   "name": "level",
    "features": [
        {
            "geometry": {
                "type": "MultiPolygon",
                "coordinates": []
            },
            "feature_type":"level",
            "id": "",
            "properties": {
                "address_id": "",
                "building_ids": [],
                "category": "unspecified",
                "display_point": {
                    "coordinates": [],
                    "type":"Point"
                },
                "name": {
                    "en": "Ground Floor"
                },
                "ordinal": 0,
                "outdoor": False,
                "restriction": None,
                "short_name": {
                    "en": "G"
                }
            },
            "type": "Feature"
        }
    ]
}

occupant_structure = {
    "type": "FeatureCollection",
   "name": "occupant",
    "features": [
        {
            "geometry": None,
            "feature_type": "occupant",
            "id": "",
            "properties": {
                "alt_name": None,
                "anchor_id": "",
                "category": "",
                "hours": "",
                "name": {
                    "en": ""
                },
                "phone": "",
                "restriction": None,
                "website": None,
                "correlation_id": None
            },
            "type": "Feature"
        }
    ]
}

opening_structure = {
    "type": "FeatureCollection",
   "name": "opening",
    "features": [
        {
            "geometry": {
                "type": "MultiLineString",
                "coordinates": []
            },
            "type":"Feature",
            "feature_type": "opening",
            "id": "",
            "properties": {
                "access_control": None,
                "accessibility": None,
                "alt_name": None,
                "category": "",
                "display_point": {
                    "coordinates": [],
                    "type":"Feature"
                },
                "door": None,
                "level_id": "",
                "name": None
            }
        }
    ]
}


unit_structure = {
    "type": "FeatureCollection",
   "name": "unit",
    "features": [
        {
            "geometry": {
                "type": "MultiPolygon",
                "coordinates": []
            }, 
            "type":"Feature",
            "feature_type": "unit",
            "id": "",
            "properties": {
                "accessibility": None,
                "alt_name": None,
                "category": "office",
                "display_point": {
                    "coordinates": [],
                    "type":"Feature"
                },
                "level_id": "",
                "name": None,
                "restriction": None
            }
        }
    ]
}

venue_structure = {
    "type": "FeatureCollection",
   "name": "venue",
    "features": [
        {
            "geometry": {
                "type": "MultiPolygon",
                "coordinates": []
            },
            "feature_type":"venue",
            "id": "",
            "properties": {
                "address_id": "",
                "alt_name": None,
                "category": "businesscampus",
                "display_point": {
                    "coordinates": [0.19458723822821,
                                    52.185771666941406],
                    "type":"Point"
                },
                "hours": "",
                "name": {
                    "en": "CPC4"
                },
                "phone": None,
                "restriction": None,
                "website": ""
            },
            "type":"Feature"
        }
    ]
}

# %%
import os
import json

# Your folder path
folder_path = "C:\\Users\\amosk\\GitHub\\Geojson_2_IMDF_Transformer\\HDI_QGIS_Geojsons"

# Map each structure to its name
structures = {
    "address": address_structure,
    "amenity": amenity_structure,
    "anchor": anchor_structure,
    "building": building_structure,
    "footprint": footprint_structure,
    "level": level_structure,
    "occupant": occupant_structure,
    "opening": opening_structure,
    "unit": unit_structure,
    "venue": venue_structure,
}

# Iterate through the files in your folder
for file_name in os.listdir(folder_path):
    # Check if the file has the .geojson extension
    if not file_name.endswith('.geojson'):
        continue

    # Extract feature type from the file name
    feature_type = file_name.split('.')[0]
    
    # If the structure doesn't exist for this file, skip it
    if feature_type not in structures:
        print(f"No structure found for {feature_type}. Skipping...")
        continue
    
    # Read the geojson file
    with open(os.path.join(folder_path, file_name), 'r') as file:
        geojson_data = json.load(file)

    # Iterate through features in the geojson file
    for feature in geojson_data.get("features", []):
        # Create a new feature based on the sample structure
        new_feature = structures[feature_type]["features"][0].copy()
        
        # Preserve existing properties in the sample structure
        for key in new_feature["properties"]:
            if key not in feature["properties"]:
                continue
            new_feature["properties"][key] = feature["properties"][key]
        
        # Copy geometry from the geojson feature
        new_feature["geometry"] = feature["geometry"]
        
        # Append the new feature to the structure
        structures[feature_type]["features"].append(new_feature)

    # Remove the sample feature
    structures[feature_type]["features"].pop(0)


from pprint import pprint
pprint(footprint_structure)
# Out:
# {'features': [{'feature_type': 'footprint',
#                'geometry': {'coordinates': [[[[0.194036592175966,
#                                                52.18556633063394],
#                                               [0.194020030108657,
#                                                52.18601144285704],
#                                               [0.194235849212565,
#                                                52.18601521142693],
#                                               [0.194240301708614,
#                                                52.18594068145665],
#                                               [0.194434607176972,
#                                                52.18594228423435],
#                                               [0.194431520646963,
#                                                52.18603007633836],
#                                               [0.194661682159675,
#                                                52.18603300744707],
#                                               [0.194664711943958,
#                                                52.185884122942404],
#                                               [0.194678585712908,
#                                                52.18550687033828],
#                                               [0.194438862594327,
#                                                52.1855035204601],
#                                               [0.194434081791392,
#                                                52.18564923992757],
#                                               [0.194283827984874,
#                                                52.18564756499388],
#                                               [0.194286517186525,
#                                                52.18557075351369],
#                                               [0.194036592175966,
#                                                52.18556633063394]]]],
#                             'type': 'MultiPolygon'},
#                'id': '',
#                'properties': {'building_ids': [],
#                               'category': 'ground',
#                               'name': None},
#                'type': 'Feature'}],
#  'name': 'footprint',
#  'type': 'FeatureCollection'}

# %%
## add UUID

import uuid

def generate_uuid_for_structures(structures):
    for structure in structures.values():
        for feature in structure['features']:
            feature['id'] = str(uuid.uuid4())
    return structures

# Map each structure to its name
structures = {
    "address": address_structure,
    "amenity": amenity_structure,
    "anchor": anchor_structure,
    "building": building_structure,
    "footprint": footprint_structure,
    "level": level_structure,
    "occupant": occupant_structure,
    "opening": opening_structure,
    "unit": unit_structure,
    "venue": venue_structure,
}

structures = generate_uuid_for_structures(structures)

# %%
pprint(unit_structure)
# Out:
# {'features': [{'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194283250799545,
#                                                52.18557310736924],
#                                               [0.194232308491778,
#                                                52.18557241003945],
#                                               [0.194231581481576,
#                                                52.18560182450015],
#                                               [0.194282067071084,
#                                                52.18560200544564],
#                                               [0.194283250799545,
#                                                52.18557310736924]]]],
#                             'type': 'MultiPolygon'},
#                'id': '3bd00727-e042-4b49-8a1a-7068f8bbeed8',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'display_point': {'coordinates': [],
#                                                 'type': 'Feature'},
#                               'level_id': '',
#                               'name': 'other office',
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194232308491778,
#                                                52.18557241003945],
#                                               [0.194147258747965,
#                                                52.18557140518274],
#                                               [0.19414607324852,
#                                                52.18559218952964],
#                                               [0.194231810319444,
#                                                52.18559256583923],
#                                               [0.194232308491778,
#                                                52.18557241003945]]]],
#                             'type': 'MultiPolygon'},
#                'id':

#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'display_point': {'coordinates': [],
#                                                 'type': 'Feature'},
#                               'level_id': '',
#                               'name': 'other office',
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194280031590874,
#                                                52.18565092354265],
#                                               [0.194276713694786,
#                                                52.18572044199834],
#                                               [0.19431815118131,
#                                                52.185721119240256],
#                                               [0.194314049489127,
#                                                52.18582505527282],
#                                               [0.194383899113887,
#                                                52.18582526603955],
#                                               [0.194385761533136,
#                                                52.18574308845524],
#                                               [0.194386786050685,
#                                                52.18572267547197],
#                                               [0.194433181781559,
#                                                52.18572268045688],
#                                               [0.194436521544227,
#                                                52.185651650402505],
#                                               [0.194280031590874,
#                                                52.18565092354265]]]],
#                             'type': 'MultiPolygon'},
#                'id': 'c9333a24-49a9-4da9-b59d-5dc6638b277e',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'display_point': {'coordinates': [],
#                                                 'type': 'Feature'},
#                               'level_id': '',
#                               'name': 'other office',
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194385448646284,
#                                                52.18577020168093],
#                                               [0.194383899113887,
#                                                52.18582526603955],
#                                               [0.194482060563663,
#                                                52.18582484590698],
#                                               [0.194482904491888,
#                                                52.185769125857206],
#                                               [0.194385448646284,
#                                                52.18577020168093]]]],
#                             'type': 'MultiPolygon'},
#                'id': 'f4297a14-71e6-4077-901b-049807056156',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'display_point': {'coordinates': [],
#                                                 'type': 'Feature'},
#                               'level_id': '',
#                               'name': 'other office',
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194482904491888,
#                                                52.185769125857206],
#                                               [0.194485475422902,
#                                                52.18572853749741],
#                                               [0.194486158394749,
#                                                52.18572225650693],
#                                               [0.194386786050685,
#                                                52.18572267547197],
#                                               [0.194385762072054,
#                                                52.18576987082599],
#                                               [0.194482904491888,
#                                                52.185769125857206]]]],
#                             'type': 'MultiPolygon'},
#                'id': 'd4d4d199-3c7a-4a8b-84ac-9ff8640c7289',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'display_point': {'coordinates': [],
#                                                 'type': 'Feature'},
#                               'level_id': '',
#                               'name': 'other office',
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194435152390625,
#                                                52.18568076956763],
#                                               [0.194671134371609,
#                                                52.185683304820614],
#                                               [0.194676646319221,
#                                                52.185510821304575],
#                                               [0.19444335018806,
#                                                52.18550651209685],
#                                               [0.194435152390625,
#                                                52.18568076956763]]]],
#                             'type': 'MultiPolygon'},
#                'id': '037ed2bb-9700-4a0a-bb9f-2c3a47402a4c',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'display_point': {'coordinates': [],
#                                                 'type': 'Feature'},
#                               'level_id': '',
#                               'name': 'other office',
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194431523230552,
#                                                52.18572248685495],
#                                               [0.194486158394749,
#                                                52.18572225650693],
#                                               [0.19448889863994,
#                                                52.185681346986044],
#                                               [0.194435152390625,
#                                                52.18568076956763],
#                                               [0.194431523230552,
#                                                52.18572248685495]]]],
#                             'type': 'MultiPolygon'},
#                'id': '8d38ba5f-fb9f-4043-934c-5b7fe43fb657',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'display_point': {'coordinates': [],
#                                                 'type': 'Feature'},
#                               'level_id': '',
#                               'name': 'other office',
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194482060563663,
#                                                52.18582484590698],
#                                               [0.194477962732577,
#                                                52.18586965018295],
#                                               [0.194664424804332,
#                                                52.18587135135343],
#                                               [0.194670774028302,
#                                                52.1856840520219],
#                                               [0.19448889863994,
#                                                52.185681346986044],
#                                               [0.194482060563663,
#                                                52.18582484590698]]]],
#                             'type': 'MultiPolygon'},
#                'id': '185b6df9-c3d0-4fc3-a818-da5fb94a4617',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'display_point': {'coordinates': [],
#                                                 'type': 'Feature'},
#                               'level_id': '',
#                               'name': 'other office',
#                               'restriction': None},
#                'type': 'Feature'}],
#  'name': 'unit',
#  'type': 'FeatureCollection'}

# %%
import json

# Extract UUID from the given structure based on the feature type.
def get_uuid_from_structure(structure, feature_type):
    for feature in structure.get('features', []):
        if feature.get('feature_type') == feature_type:
            return feature.get('id')
    return None

# Update the address_id, building_ids, and level_id in the given structure with the provided UUIDs.
def update_ids_in_structure(structure, address_uuid, building_uuid, level_uuid):
    for feature in structure.get('features', []):
        # Only replace the keys if they already exist in the properties
        if 'address_id' in feature['properties']:
            feature['properties']['address_id'] = address_uuid
        if 'building_ids' in feature['properties']:
            feature['properties']['building_ids'] = [building_uuid]
        if 'level_id' in feature['properties']:
            feature['properties']['level_id'] = level_uuid

def main():
    # Extract UUIDs from address, building, and level structures
    address_uuid = get_uuid_from_structure(address_structure, 'address')
    building_uuid = get_uuid_from_structure(building_structure, 'building')
    level_uuid = get_uuid_from_structure(level_structure, 'level')

    # List of structures that need to be updated
    structures_to_update = [level_structure, venue_structure, opening_structure, unit_structure, 
                            anchor_structure, amenity_structure, footprint_structure, building_structure]

    for struct in structures_to_update:
        update_ids_in_structure(struct, address_uuid, building_uuid, level_uuid)
        # print(f"Updated IDs in {struct['features'][0]['feature_type']} structure")

main()


# pprint(unit_structure)
# print(footprint_structure)

# %%
pprint(amenity_structure)
# Out:
# {'features': [{'feature_type': 'amenity',
#                'geometry': {'coordinates': [0.194257852974217,
#                                             52.185638878340924],
#                             'type': 'Point'},
#                'id': 'db3b0aef-8b80-4469-8829-24afb7c0aeaf',
#                'properties': {'accessibility': None,
#                               'address_id': '591f4877-e985-4ad4-9bf1-8ccce24e5aec',
#                               'alt_name': None,
#                               'category': 'restroom',
#                               'correlation_id': None,
#                               'hours': None,
#                               'name': None,
#                               'phone': None,
#                               'unit_ids': [],
#                               'website': None},
#                'type': 'Feature'},
#               {'feature_type': 'amenity',
#                'geometry': {'coordinates': [0.194263281915114,
#                                             52.185746682575996],
#                             'type': 'Point'},
#                'id': 'ee03e5a6-e271-4387-86b0-d07389382e9f',
#                'properties': {'accessibility': None,
#                               'address_id': '591f4877-e985-4ad4-9bf1-8ccce24e5aec',
#                               'alt_name': None,
#                               'category': 'restroom',
#                               'correlation_id': None,
#                               'hours': None,
#                               'name': None,
#                               'phone': None,
#                               'unit_ids': [],
#                               'website': None},
#                'type': 'Feature'},
#               {'feature_type': 'amenity',
#                'geometry': {'coordinates': [0.194259639398593,
#                                             52.18579860537545],
#                             'type': 'Point'},
#                'id': 'e8c8ba34-be69-4fdd-b8b0-2b97b4d44e72',
#                'properties': {'accessibility': None,
#                               'address_id': '591f4877-e985-4ad4-9bf1-8ccce24e5aec',
#                               'alt_name': None,
#                               'category': 'restroom',
#                               'correlation_id': None,
#                               'hours': None,
#                               'name': None,
#                               'phone': None,
#                               'unit_ids': [],
#                               'website': None},
#                'type': 'Feature'},
#               {'feature_type': 'amenity',
#                'geometry': {'coordinates': [0.194426056872151,
#                                             52.185800001148756],
#                             'type': 'Point'},
#                'id': '101c1458-6c37-4518-bd11-852c53da7a53',
#                'properties': {'accessibility': None,
#                               'address_id': '591f4877-e985-4ad4-9bf1-8ccce24e5aec',
#                               'alt_name': None,
#                               'category': 'restroom',
#                               'correlation_id': None,
#                               'hours': None,
#                               'name': None,
#                               'phone': None,
#                               'unit_ids': [],
#                               'website': None},
#                'type': 'Feature'},
#               {'feature_type': 'amenity',
#                'geometry': {'coordinates': [0.194434252534323,
#                                             52.18574472849093],
#                             'type': 'Point'},
#                'id': '0f70f624-acd5-4978-8d75-82de2cc510c8',
#                'properties': {'accessibility': None,
#                               'address_id': '591f4877-e985-4ad4-9bf1-8ccce24e5aec',
#                               'alt_name': None,
#                               'category': 'restroom',
#                               'correlation_id': None,
#                               'hours': None,
#                               'name': None,
#                               'phone': None,
#                               'unit_ids': [],
#                               'website': None},
#                'type': 'Feature'}],
#  'name': 'amenity',
#  'type': 'FeatureCollection'}

# %%
# Ray-casting algorithm to determine if a point is inside a polygon
def is_point_inside_polygon(point, polygon):
    x, y = point
    oddNodes = False
    j = len(polygon) - 1

    for i in range(len(polygon)):
        xi, yi = polygon[i]
        xj, yj = polygon[j]
        if yi < y and yj >= y or yj < y and yi >= y:
            if xi + (y - yi) / (yj - yi) * (xj - xi) < x:
                oddNodes = not oddNodes
        j = i
    return oddNodes

anchor_structure_new = {'features' : []}
amenity_structure_new = {'features' : []}

import copy

for anchor_feature in anchor_structure['features']:
    point = tuple(anchor_feature['geometry']['coordinates'])

    for unit_feature in unit_structure['features']:
        polygon = unit_feature['geometry']['coordinates'][0][0]
        if is_point_inside_polygon(point, polygon):
            new_anchor_feature = copy.deepcopy(anchor_feature)  # Create a deep copy
            new_anchor_feature['properties']['unit_id'] = unit_feature['id']
            anchor_structure_new['features'].append(new_anchor_feature)
            break


for amenity_feature in amenity_structure['features']:
    point = tuple(amenity_feature['geometry']['coordinates'])

    for unit_feature in unit_structure['features']:
        polygon = unit_feature['geometry']['coordinates'][0][0]
        if is_point_inside_polygon(point, polygon):
            new_amenity_feature = copy.deepcopy(amenity_feature)  # Create a deep copy
            new_amenity_feature['properties']['unit_ids'] = [unit_feature['id']]
            amenity_structure_new['features'].append(new_amenity_feature)
            break

# %%
# pprint(anchor_structure_new)
anchor_structure = anchor_structure_new
anchor_structure["type"] = "FeatureCollection"
anchor_structure["name"] = "anchor"
# pprint(anchor_structure)

amenity_structure = amenity_structure_new
amenity_structure["type"] = "FeatureCollection"
amenity_structure["name"] = "amenity"
pprint(amenity_structure)
# Out:
# {'features': [{'feature_type': 'amenity',
#                'geometry': {'coordinates': [0.194257852974217,
#                                             52.185638878340924],
#                             'type': 'Point'},
#                'id': 'db3b0aef-8b80-4469-8829-24afb7c0aeaf',
#                'properties': {'accessibility': None,
#                               'address_id': '591f4877-e985-4ad4-9bf1-8ccce24e5aec',
#                               'alt_name': None,
#                               'category': 'restroom',
#                               'correlation_id': None,
#                               'hours': None,
#                               'name': None,
#                               'phone': None,
#                               'unit_ids': ['20e1abb6-0c11-4e30-b3cd-aaeeea71a4c3'],
#                               'website': None},
#                'type': 'Feature'},
#               {'feature_type': 'amenity',
#                'geometry': {'coordinates': [0.194263281915114,
#                                             52.185746682575996],
#                             'type': 'Point'},
#                'id': 'ee03e5a6-e271-4387-86b0-d07389382e9f',
#                'properties': {'accessibility': None,
#                               'address_id': '591f4877-e985-4ad4-9bf1-8ccce24e5aec',
#                               'alt_name': None,
#                               'category': 'restroom',
#                               'correlation_id': None,
#                               'hours': None,
#                               'name': None,
#                               'phone': None,
#                               'unit_ids': ['00b6a83e-a91d-4f55-8add-5036f9cfdbd1'],
#                               'website': None},
#                'type': 'Feature'},
#               {'feature_type': 'amenity',
#                'geometry': {'coordinates': [0.194259639398593,
#                                             52.18579860537545],
#                             'type': 'Point'},
#                'id': 'e8c8ba34-be69-4fdd-b8b0-2b97b4d44e72',
#                'properties': {'accessibility': None,
#                               'address_id': '591f4877-e985-4ad4-9bf1-8ccce24e5aec',
#                               'alt_name': None,
#                               'category': 'restroom',
#                               'correlation_id': None,
#                               'hours': None,
#                               'name': None,
#                               'phone': None,
#                               'unit_ids': ['af4cc6c2-62ab-4989-a33e-dd3c5d25ddde'],
#                               'website': None},
#                'type': 'Feature'},
#               {'feature_type': 'amenity',
#                'geometry': {'coordinates': [0.194426056872151,
#                                             52.185800001148756],
#                             'type': 'Point'},
#                'id': '101c1458-6c37-4518-bd11-852c53da7a53',
#                'properties': {'accessibility': None,
#                               'address_id': '591f4877-e985-4ad4-9bf1-8ccce24e5aec',
#                               'alt_name': None,
#                               'category': 'restroom',
#                               'correlation_id': None,
#                               'hours': None,
#                               'name': None,
#                               'phone': None,
#                               'unit_ids': ['f4297a14-71e6-4077-901b-049807056156'],
#                               'website': None},
#                'type': 'Feature'},
#               {'feature_type': 'amenity',
#                'geometry': {'coordinates': [0.194434252534323,
#                                             52.18574472849093],
#                             'type': 'Point'},
#                'id': '0f70f624-acd5-4978-8d75-82de2cc510c8',
#                'properties': {'accessibility': None,
#                               'address_id': '591f4877-e985-4ad4-9bf1-8ccce24e5aec',
#                               'alt_name': None,
#                               'category': 'restroom',
#                               'correlation_id': None,
#                               'hours': None,
#                               'name': None,
#                               'phone': None,
#                               'unit_ids': ['d4d4d199-3c7a-4a8b-84ac-9ff8640c7289'],
#                               'website': None},
#                'type': 'Feature'}],
#  'name': 'amenity',
#  'type': 'FeatureCollection'}

# %%
import json


def compute_polygon_centroid(polygon):
    """
    Compute the centroid of a polygon.
    """
    area = 0.0
    x_centroid = 0.0
    y_centroid = 0.0
    
    for i in range(-1, len(polygon)-1):
        xi, yi = polygon[i]
        xi1, yi1 = polygon[i+1]
        
        fi = xi * yi1 - xi1 * yi
        area += fi
        x_centroid += (xi + xi1) * fi
        y_centroid += (yi + yi1) * fi
    
    area /= 2.0
    x_centroid /= (6.0 * area)
    y_centroid /= (6.0 * area)
    
    return [x_centroid, y_centroid]


def update_unit_display_point():
    """
    Update the display_point for each unit with the centroid of the unit polygon.
    """

    for unit in unit_structure['features']:
        polygon = unit['geometry']['coordinates'][0][0]
        centroid = compute_polygon_centroid(polygon)
        
        unit['properties']['display_point'] = {
            "coordinates": centroid,
            "type": "Point"
        }

update_unit_display_point()
# Iterate through each feature and update the "name" property
for feature in unit_structure["features"]:
    feature["properties"]["name"] = {"en": "input name here"}
pprint(unit_structure)
# Out:
# {'features': [{'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194283250799545,
#                                                52.18557310736924],
#                                               [0.194232308491778,
#                                                52.18557241003945],
#                                               [0.194231581481576,
#                                                52.18560182450015],
#                                               [0.194282067071084,
#                                                52.18560200544564],
#                                               [0.194283250799545,
#                                                52.18557310736924]]]],
#                             'type': 'MultiPolygon'},
#                'id': '3bd00727-e042-4b49-8a1a-7068f8bbeed8',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'display_point': {'coordinates': [0.1945757887714961,
#                                                                 52.18577698577574],
#                                                 'type': 'Point'},
#                               'level_id': '9244f0bb-003c-478c-be23-add9473e7166',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194232308491778,
#                                                52.18557241003945],
#                                               [0.194147258747965,
#                                                52.18557140518274],
#                                               [0.19414607324852,
#                                                52.18559218952964],
#                                               [0.194231810319444,
#                                                52.18559256583923],
#                                               [0.194232308491778,
#                                                52.18557241003945]]]],
#                             'type': 'MultiPolygon'},
#                'id': '491e9a49-701f-400a-be83-b4c1e8caccf9',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'display_point': {'coordinates': [0.1945757887714961,
#                                                                 52.18577698577574],
#                                                 'type': 'Point'},
#                               'level_id': '9244f0bb-003c-478c-be23-add9473e7166',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194146678811163,
#                                                52.18557139792483],
#                                               [0.194089819610152,
#                                                52.1855706863312],
#                                               [0.194038717222795,
#                                                52.185570340074925],
#                                               [0.194038604466883,
#                                                52.18559963345006],
#                                               [0.194145466162433,
#                                                52.18560019200002],
#                                               [0.19414607324852,
#                                                52.18559218952964],
#                                               [0.194146678811163,
#                                                52.18557139792483]]]],
#                             'type': 'MultiPolygon'},
#                'id': '62de42f2-d466-47fb-bc48-30827f0abfd9',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'display_point': {'coordinates': [0.1945757887714961,
#                                                                 52.18577698577574],
#                                                 'type': 'Point'},
#                               'level_id': '9244f0bb-003c-478c-be23-add9473e7166',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194069886849902,
#                                                52.18559979695835],
#                                               [0.194038604466883,
#                                                52.18559963345006],
#                                               [0.194038006551374,
#                                                52.18561336124907],
#                                               [0.194069276858547,
#                                                52.18561340537819],
#                                               [0.194069886849902,
#                                                52.18559979695835]]]],
#                             'type': 'MultiPolygon'},
#                'id': '5493478b-333f-4700-85c4-5f2c737c219f',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'display_point': {'coordinates': [0.1945757887714961,
#                                                                 52.18577698577574],
#                                                 'type': 'Point'},
#                               'level_id': '9244f0bb-003c-478c-be23-add9473e7166',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194037558702104,
#                                                52.18562364361006],
#                                               [0.194035313705211,
#                                                52.18567518740834],
#                                               [0.194090524871573,
#                                                52.185675750137676],
#                                               [0.194093256758973,
#                                                52.1856245716102],
#                                               [0.194037558702104,
#                                                52.18562364361006]]]],
#                             'type': 'MultiPolygon'},
#                'id': 'd50d3491-49e3-4a52-a455-df512342e815',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'display_point': {'coordinates': [0.1945757887714961,
#                                                                 52.18577698577574],
#                                                 'type': 'Point'},
#                               'level_id': '9244f0bb-003c-478c-be23-add9473e7166',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194280082778044,
#                                                52.18564576372339],
#                                               [0.194228712842049,
#                                                52.185645578076596],
#                                               [0.194231806940102,
#                                                52.185592702565636],
#                                               [0.194146301708928,
#                                                52.185592190532375],
#                                               [0.194145466162433,
#                                                52.18560019200002],
#                                               [0.194069868924426,
#                                                52.185600196861444],
#                                               [0.194069276858547,
#                                                52.18561340537819],
#                                               [0.194038006551374,
#                                                52.18561336124907],
#                                               [0.194037542934714,
#                                                52.185624005620205],
#                                               [0.194093243803826,
#                                                52.18562493962979],
#                                               [0.194091448879848,
#                                                52.185675928385116],
#                                               [0.194278114472344,
#                                                52.18567761117395],
#                                               [0.194280105317845,
#                                                52.185649897211306],
#                                               [0.194280082778044,
#                                                52.18564576372339]]]],
#                             'type': 'MultiPolygon'},
#                'id': '29d4df7d-3aa7-4b5f-a895-9ac9cc83c07a',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'display_point': {'coordinates': [0.1945757887714961,
#                                                                 52.18577698577574],
#                                                 'type': 'Point'},
#                               'level_id': '9244f0bb-003c-478c-be23-add9473e7166',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.

#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'display_point': {'coordinates': [0.1945757887714961,
#                                                                 52.18577698577574],
#                                                 'type': 'Point'},
#                               'level_id': '9244f0bb-003c-478c-be23-add9473e7166',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194482060563663,
#                                                52.18582484590698],
#                                               [0.194477962732577,
#                                                52.18586965018295],
#                                               [0.194664424804332,
#                                                52.18587135135343],
#                                               [0.194670774028302,
#                                                52.1856840520219],
#                                               [0.19448889863994,
#                                                52.185681346986044],
#                                               [0.194482060563663,
#                                                52.18582484590698]]]],
#                             'type': 'MultiPolygon'},
#                'id': '185b6df9-c3d0-4fc3-a818-da5fb94a4617',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'display_point': {'coordinates': [0.1945757887714961,
#                                                                 52.18577698577574],
#                                                 'type': 'Point'},
#                               'level_id': '9244f0bb-003c-478c-be23-add9473e7166',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'}],
#  'name': 'unit',
#  'type': 'FeatureCollection'}

# %%
## Transform opening.geojson by setting its display point as the centre of the line

import json

def compute_line_center(coordinates):
    """
    Compute the center of a line given its coordinates.
    """
    x_coords = [coord[0] for coord in coordinates[0]]
    y_coords = [coord[1] for coord in coordinates[0]]
    
    return [sum(x_coords) / len(x_coords), sum(y_coords) / len(y_coords)]

def update_openings():
    """
    Update the display_point and category for each opening.
    """


    for opening in opening_structure['features']:
        center = compute_line_center(opening['geometry']['coordinates'])
        opening['properties']['display_point'] = {
            "coordinates": center,
            "type": "Point"
        }
        opening['properties']['category'] = "pedestrian"

# Sample usage:
update_openings()

# %%
## generate occupant.geojson that references the UUID

import json
import os
import uuid


# Generate features for the occupant.geojson
for feature in anchor_structure["features"]:
    occupant_feature = {
        "geometry": None,
        "feature_type": "occupant",
        "id": str(uuid.uuid4()),  
        "properties": {
            "alt_name": None,
            "category": None,
            "hours": "",
            "name": {
                "en": "Test"
            },
            "anchor_id": feature["id"],
            "phone": "",
            "restriction": None,
            "website": None,
            "correlation_id": None
        },
        "type": "Feature"
    }
    occupant_structure["features"].append(occupant_feature)

 # Remove the sample feature
occupant_structure["features"].pop(0)

from pprint import pprint
pprint(occupant_structure)
# Out:
# {'features': [{'feature_type': 'occupant',
#                'geometry': None,
#                'id': '827c292d-d981-4d3a-9694-3992245092c2',
#                'properties': {'alt_name': None,
#                               'anchor_id': 'ef43a49e-e57d-45d1-8438-87aacf25d804',
#                               'category': None,
#                               'correlation_id': None,
#                               'hours': '',
#                               'name': {'en': 'Test'},
#                               'phone': '',
#                               'restriction': None,
#                               'website': None},
#                'type': 'Feature'},
#               {'feature_type': 'occupant',
#                'geometry': None,
#                'id': '25ff50fb-0dde-49ae-8348-ebf77033b154',
#                'properties': {'alt_name': None,
#                               'anchor_id': 'f2c02c60-e04d-432e-9f24-891ee9307181',
#                               'category': None,
#                               'correlation_id': None,
#                               'hours': '',
#                               'name': {'en': 'Test'},
#                               'phone': '',
#                               'restriction': None,
#                               'website': None},
#                'type': 'Feature'},
#               {'feature_type': 'occupant',
#                'geometry': None,
#                'id': 'ca16727a-e657-449a-bf67-537e704197e5',
#                'properties': {'alt_name': None,
#                               'anchor_id': '71b09a9d-3bba-4e91-a25d-89ce51e2cbc6',
#                               'category': None,
#                               'correlation_id': None,
#                               'hours': '',
#                               'name': {'en': 'Test'},
#                               'phone': '',
#                               'restriction': None,
#                               'website': None},
#                'type': 'Feature'},
#               {'feature_type': 'occupant',
#                'geometry': None,
#                'id': '864ab7f4-fd94-4560-b6c1-9dcdfad8937d',
#                'properties': {'alt_name': None,
#                               'anchor_id': 'c8e11b4f-67e2-4492-a571-6cdae9a48435',
#                               'category': None,
#                               'correlation_id': None,
#                               'hours': '',
#                               'name': {'en': 'Test'},
#                               'phone': '',
#                               'restriction': None,
#                               'website': None},
#                'type': 'Feature'}],
#  'name': 'occupant',
#  'type': 'FeatureCollection'}

# %%
import json
import os

# List of your 10 structures (dictionaries)
structures = [address_structure, amenity_structure, anchor_structure, building_structure, footprint_structure, level_structure, occupant_structure, opening_structure, unit_structure, venue_structure]

# Specify the base directory where you want to save the GeoJSON files
base_directory = "C:\\Users\\amosk\\GitHub\\Geojson_2_IMDF_Transformer\\IMDF"

# Loop through the structures and save each one to a separate GeoJSON file
for structure_name, structure in zip(["address", "amenity", "anchor", "building", "footprint", "level", "occupant", "opening", "unit", "venue"], structures):
    # Generate the file name
    geojson_file_name = f"{structure_name}.geojson"
    
    # Construct the full file path
    file_path = os.path.join(base_directory, geojson_file_name)
    
    # Save the structure to the GeoJSON file
    with open(file_path, "w") as geojson_file:
        json.dump(structure, geojson_file, indent=2)
