# %%
## initialize dictionaries with some predefined values

address_structure = {
    "type": "FeatureCollection",
    "name": "address",
    "features": [
        {
            "geometry": None,
            "feature_type":"address",
            "id": "",
            "properties": {
                "address": "CPC4, Capital Park, Fulbourn, Cambridge",
                "country": "GB",
                "locality": "Cambridge",
                "postal_code": "CB21 5XE",
                "postal_code_ext": None,
                "province": "GB-CAM",
                "unit": None
            },
            "type": "Feature"
        }
    ]
}

amenity_structure = {
    "type": "FeatureCollection",
   "name": "amenity",
    "features": [
        {
            "geometry": {
                "type": "Point",
                "coordinates": []
            },
            "type": "Feature",
            "feature_type":"amenity",
            "id": "",
            "properties": {
                "accessibility": None,
                "address_id": "",
                "alt_name": None,
                "category": "restroom",
                "correlation_id": None,
                "hours": None,
                "name": None,
                "phone": None,
                "unit_ids": [],
                "website": None
            }
        }
    ]
}

anchor_structure = {
    "type": "FeatureCollection",
   "name": "anchor",
    "features": [
        {
            "geometry": {
                "type": "Point",
                "coordinates": []
            },
            "feature_type":"anchor",
            "id": "",
            "properties": {
                "address_id": "",
                "unit_id": ""
            },
            "type": "Feature"
        }
    ]
}

building_structure = {
    "type": "FeatureCollection",
   "name": "building",
        "features": [
        {
            "geometry": None,
            "feature_type":"building",
            "id": "",
            "properties": {
                "address_id": "",
                "alt_name": None,
                "category": "unspecified",
                "display_point": {
                    "coordinates": [0.19458723822821,
          52.185771666941406],
                    "type":"Point"
                },
                "name": {
                    "en": "CPC4"
                },
                "restriction": None
            },
            "type": "Feature"
        }
    ]
}

footprint_structure = {
    "type": "FeatureCollection",
    "name": "footprint",
     "features": [
        {
            "geometry": {
                "type": "MultiPolygon",
                "coordinates": []
            },
            "feature_type":"footprint",
            "id": "",
            "properties": {
                "building_ids": [],
                "category": "ground",
                "name": None
            },
            "type": "Feature"
        }
    ]
}

level_structure = {
    "type": "FeatureCollection",
   "name": "level",
    "features": [
        {
            "geometry": {
                "type": "MultiPolygon",
                "coordinates": []
            },
            "feature_type":"level",
            "id": "",
            "properties": {
                "address_id": "",
                "building_ids": [],
                "category": "unspecified",
                "display_point": {
                    "coordinates": [0.19458723822821,
          52.185771666941406],
                    "type":"Point"
                },
                "name": {
                    "en": "Ground Floor"
                },
                "ordinal": 0,
                "outdoor": False,
                "restriction": None,
                "short_name": {
                    "en": "G"
                }
            },
            "type": "Feature"
        }
    ]
}

occupant_structure = {
    "type": "FeatureCollection",
   "name": "occupant",
    "features": [
        {
            "geometry": None,
            "feature_type": "occupant",
            "id": "",
            "properties": {
                "alt_name": None,
                "anchor_id": "",
                "category": "",
                "hours": "",
                "name": {
                    "en": ""
                },
                "phone": "",
                "restriction": None,
                "website": None,
                "correlation_id": None
            },
            "type": "Feature"
        }
    ]
}

opening_structure = {
    "type": "FeatureCollection",
   "name": "opening",
    "features": [
        {
            "geometry": {
                "type": "MultiLineString",
                "coordinates": []
            },
            "type":"Feature",
            "feature_type": "opening",
            "id": "",
            "properties": {
                "access_control": None,
                "accessibility": None,
                "alt_name": None,
                "category": "",
                "display_point": {
                    "coordinates": [],
                    "type":"Feature"
                },
                "door": None,
                "level_id": "",
                "name": None
            }
        }
    ]
}


unit_structure = {
    "type": "FeatureCollection",
   "name": "unit",
    "features": [
        {
            "geometry": {
                "type": "MultiPolygon",
                "coordinates": []
            }, 
            "type":"Feature",
            "feature_type": "unit",
            "id": "",
            "properties": {
                "accessibility": None,
                "alt_name": None,
                "category": "office",
                "display_point": {
                    "coordinates": [],
                    "type":"Feature"
                },
                "level_id": "",
                "name": None,
                "restriction": None
            }
        }
    ]
}

venue_structure = {
    "type": "FeatureCollection",
   "name": "venue",
    "features": [
        {
            "geometry": {
                "type": "MultiPolygon",
                "coordinates": []
            },
            "feature_type":"venue",
            "id": "",
            "properties": {
                "address_id": "",
                "alt_name": None,
                "category": "businesscampus",
                "display_point": {
                    "coordinates": [0.19458723822821,
                                    52.185771666941406],
                    "type":"Point"
                },
                "hours": "",
                "name": {
                    "en": "CPC4"
                },
                "phone": None,
                "restriction": None,
                "website": ""
            },
            "type":"Feature"
        }
    ]
}

# %%
import os
import json

# Your folder path
folder_path = "C:\\Users\\amosk\\GitHub\\Geojson_2_IMDF_Transformer\\HDI_QGIS_Geojsons"

# Map each structure to its name
structures = {
    "address": address_structure,
    "amenity": amenity_structure,
    "anchor": anchor_structure,
    "building": building_structure,
    "footprint": footprint_structure,
    "level": level_structure,
    "occupant": occupant_structure,
    "opening": opening_structure,
    "unit": unit_structure,
    "venue": venue_structure,
}

# Iterate through the files in your folder
for file_name in os.listdir(folder_path):
    # Check if the file has the .geojson extension
    if not file_name.endswith('.geojson'):
        continue

    # Extract feature type from the file name
    feature_type = file_name.split('.')[0]
    
    # If the structure doesn't exist for this file, skip it
    if feature_type not in structures:
        print(f"No structure found for {feature_type}. Skipping...")
        continue
    
    # Read the geojson file
    with open(os.path.join(folder_path, file_name), 'r') as file:
        geojson_data = json.load(file)

    # Iterate through features in the geojson file
    for feature in geojson_data.get("features", []):
        # Create a new feature based on the sample structure
        new_feature = structures[feature_type]["features"][0].copy()
        
        # Preserve existing properties in the sample structure
        for key in new_feature["properties"]:
            if key not in feature["properties"]:
                continue
            new_feature["properties"][key] = feature["properties"][key]
        
        # Copy geometry from the geojson feature
        new_feature["geometry"] = feature["geometry"]
        
        # Append the new feature to the structure
        structures[feature_type]["features"].append(new_feature)

    # Remove the sample feature
    structures[feature_type]["features"].pop(0)


from pprint import pprint
pprint(footprint_structure)
# Out:
# {'features': [{'feature_type': 'footprint',
#                'geometry': {'coordinates': [[[[0.194036592175966,
#                                                52.18556633063394],
#                                               [0.194020030108657,
#                                                52.18601144285704],
#                                               [0.194235849212565,
#                                                52.18601521142693],
#                                               [0.194240301708614,
#                                                52.18594068145665],
#                                               [0.194434607176972,
#                                                52.18594228423435],
#                                               [0.194431520646963,
#                                                52.18603007633836],
#                                               [0.194661682159675,
#                                                52.18603300744707],
#                                               [0.194664711943958,
#                                                52.185884122942404],
#                                               [0.194678585712908,
#                                                52.18550687033828],
#                                               [0.194438862594327,
#                                                52.1855035204601],
#                                               [0.194434081791392,
#                                                52.18564923992757],
#                                               [0.194283827984874,
#                                                52.18564756499388],
#                                               [0.194286517186525,
#                                                52.18557075351369],
#                                               [0.194036592175966,
#                                                52.18556633063394]]]],
#                             'type': 'MultiPolygon'},
#                'id': '',
#                'properties': {'building_ids': [],
#                               'category': 'ground',
#                               'name': None},
#                'type': 'Feature'}],
#  'name': 'footprint',
#  'type': 'FeatureCollection'}

# %%
## add UUID

import uuid

def generate_uuid_for_structures(structures):
    for structure in structures.values():
        for feature in structure['features']:
            feature['id'] = str(uuid.uuid4())
    return structures

# Map each structure to its name
structures = {
    "address": address_structure,
    "amenity": amenity_structure,
    "anchor": anchor_structure,
    "building": building_structure,
    "footprint": footprint_structure,
    "level": level_structure,
    "occupant": occupant_structure,
    "opening": opening_structure,
    "unit": unit_structure,
    "venue": venue_structure,
}

structures = generate_uuid_for_structures(structures)

# %%
pprint(unit_structure)
# Out:
# {'features': [{'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194283250799545,
#                                                52.18557310736924],
#                                               [0.194232308491778,
#                                                52.18557241003945],
#                                               [0.194231581481576,
#                                                52.18560182450015],
#                                               [0.194282067071084,
#                                                52.18560200544564],
#                                               [0.194283250799545,
#                                                52.18557310736924]]]],
#                             'type': 'MultiPolygon'},
#                'id': 'c833b87f-80d2-4d87-983e-3252523403a7',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'display_point': {'coordinates': [],
#                                                 'type': 'Feature'},
#                               'level_id': '',
#                               'name': 'other office',
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194232308491778,
#                                                52.18557241003945],
#                                               [0.194147258747965,
#                                                52.18557140518274],
#                                               [0.19414607324852,
#                                                52.18559218952964],
#                                               [0.194231810319444,
#                                                52.18559256583923],
#                                               [0.194232308491778,
#                                                52.18557241003945]]]],
#                             'type': 'MultiPolygon'},
#                'id': 'd32ebe44-f48a-43d7-a5b1-34d9e7fbfa5c',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'display_point': {'coordinates': [],
#                                                 'type': 'Feature'},
#                               'level_id': '',
#                               'name': 'other office',
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194146678811163,
#                                                52.18557139792483],
#                                               [0.194089819610152,
#                                                52.1855706863312],
#                                               [0.194038717222795,
#                                                52.185570340074925],
#                                               [0.194038604466883,
#                                                52.18559963345006],
#                                               [0.194145466162433,
#                                                52.18560019200002],
#                                               [0.19414607324852,
#                                                52.18559218952964],
#                                               [0.194146678811163,
#                                                52.18557139792483]]]],
#                             'type': 'MultiPolygon'},
#                'id': 'a14b1c03-7e36-4b36-bd0c-60513c1e995f',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'display_point': {'coordinates': [],
#                                                 'type': 'Feature'},
#                               'level_id': '',
#                               'name': 'other office',
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194069886849902,
#                                                52.18559979695835],
#                                               [0.194038604466883,
#                                                52.18559963345006],
#                                               [0.194038006551374,
#                                                52.18561336124907],
#                                               [0.194069276858547,
#                                                52.18561340537819],
#                                               [0.194069886849902,
#                                                52.18559979695835]]]],
#                             'type': 'MultiPolygon'},
#                'id': 'f1537975-b88c-4ad4-862b-ca594e6b98fa',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'display_point': {'coordinates': [],
#                                                 'type': 'Feature'},
#                               'level_id': '',
#                               'name': 'other office',
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194037558702104,
#                                                52.18562364361006],
#                                               [0.194035313705211,
#                                                52.18567518740834],
#                                               [0.194090524871573,
#                                                52.185675750137676],
#                                               [0.194093256758973,
#                                                52.1856245716102],
#                                               [0.194037558702104,
#                                                52.18562364361006]]]],
#                             'type': 'MultiPolygon'},
#                'id': 

#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'display_point': {'coordinates': [],
#                                                 'type': 'Feature'},
#                               'level_id': '',
#                               'name': 'other office',
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194482060563663,
#                                                52.18582484590698],
#                                               [0.194477962732577,
#                                                52.18586965018295],
#                                               [0.194664424804332,
#                                                52.18587135135343],
#                                               [0.194670774028302,
#                                                52.1856840520219],
#                                               [0.19448889863994,
#                                                52.185681346986044],
#                                               [0.194482060563663,
#                                                52.18582484590698]]]],
#                             'type': 'MultiPolygon'},
#                'id': 'd91ff069-6fd7-4684-bccf-4e9e74d47a32',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'display_point': {'coordinates': [],
#                                                 'type': 'Feature'},
#                               'level_id': '',
#                               'name': 'other office',
#                               'restriction': None},
#                'type': 'Feature'}],
#  'name': 'unit',
#  'type': 'FeatureCollection'}

# %%
import json

# Extract UUID from the given structure based on the feature type.
def get_uuid_from_structure(structure, feature_type):
    for feature in structure.get('features', []):
        if feature.get('feature_type') == feature_type:
            return feature.get('id')
    return None

# Update the address_id, building_ids, and level_id in the given structure with the provided UUIDs.
def update_ids_in_structure(structure, address_uuid, building_uuid, level_uuid):
    for feature in structure.get('features', []):
        # Only replace the keys if they already exist in the properties
        if 'address_id' in feature['properties']:
            feature['properties']['address_id'] = address_uuid
        if 'building_ids' in feature['properties']:
            feature['properties']['building_ids'] = [building_uuid]
        if 'level_id' in feature['properties']:
            feature['properties']['level_id'] = level_uuid

def main():
    # Extract UUIDs from address, building, and level structures
    address_uuid = get_uuid_from_structure(address_structure, 'address')
    building_uuid = get_uuid_from_structure(building_structure, 'building')
    level_uuid = get_uuid_from_structure(level_structure, 'level')

    # List of structures that need to be updated
    structures_to_update = [level_structure, venue_structure, opening_structure, unit_structure, 
                            anchor_structure, amenity_structure, footprint_structure, building_structure]

    for struct in structures_to_update:
        update_ids_in_structure(struct, address_uuid, building_uuid, level_uuid)
        # print(f"Updated IDs in {struct['features'][0]['feature_type']} structure")

main()


# pprint(unit_structure)
# print(footprint_structure)

# %%
pprint(amenity_structure)
# Out:
# {'features': [{'feature_type': 'amenity',
#                'geometry': {'coordinates': [0.194257852974217,
#                                             52.185638878340924],
#                             'type': 'Point'},
#                'id': 'd56836d6-ae07-41d7-a889-56a93f7f99a0',
#                'properties': {'accessibility': None,
#                               'address_id': 'e6fcbe2d-a0a8-4f4f-80fa-438694e1d185',
#                               'alt_name': None,
#                               'category': 'restroom',
#                               'correlation_id': None,
#                               'hours': None,
#                               'name': None,
#                               'phone': None,
#                               'unit_ids': [],
#                               'website': None},
#                'type': 'Feature'},
#               {'feature_type': 'amenity',
#                'geometry': {'coordinates': [0.194263281915114,
#                                             52.185746682575996],
#                             'type': 'Point'},
#                'id': 'f87ac44b-058f-4b91-a041-222c92364ad3',
#                'properties': {'accessibility': None,
#                               'address_id': 'e6fcbe2d-a0a8-4f4f-80fa-438694e1d185',
#                               'alt_name': None,
#                               'category': 'restroom',
#                               'correlation_id': None,
#                               'hours': None,
#                               'name': None,
#                               'phone': None,
#                               'unit_ids': [],
#                               'website': None},
#                'type': 'Feature'},
#               {'feature_type': 'amenity',
#                'geometry': {'coordinates': [0.194259639398593,
#                                             52.18579860537545],
#                             'type': 'Point'},
#                'id': '639a8e58-b928-4dde-8ad7-5ffb21287a49',
#                'properties': {'accessibility': None,
#                               'address_id': 'e6fcbe2d-a0a8-4f4f-80fa-438694e1d185',
#                               'alt_name': None,
#                               'category': 'restroom',
#                               'correlation_id': None,
#                               'hours': None,
#                               'name': None,
#                               'phone': None,
#                               'unit_ids': [],
#                               'website': None},
#                'type': 'Feature'},
#               {'feature_type': 'amenity',
#                'geometry': {'coordinates': [0.194426056872151,
#                                             52.185800001148756],
#                             'type': 'Point'},
#                'id': 'f214f4cf-ed1d-4a80-aeeb-b5ea1bac63bb',
#                'properties': {'accessibility': None,
#                               'address_id': 'e6fcbe2d-a0a8-4f4f-80fa-438694e1d185',
#                               'alt_name': None,
#                               'category': 'restroom',
#                               'correlation_id': None,
#                               'hours': None,
#                               'name': None,
#                               'phone': None,
#                               'unit_ids': [],
#                               'website': None},
#                'type': 'Feature'},
#               {'feature_type': 'amenity',
#                'geometry': {'coordinates': [0.194434252534323,
#                                             52.18574472849093],
#                             'type': 'Point'},
#                'id': '828bd436-e471-4cf3-84e4-0b39d2603df6',
#                'properties': {'accessibility': None,
#                               'address_id': 'e6fcbe2d-a0a8-4f4f-80fa-438694e1d185',
#                               'alt_name': None,
#                               'category': 'restroom',
#                               'correlation_id': None,
#                               'hours': None,
#                               'name': None,
#                               'phone': None,
#                               'unit_ids': [],
#                               'website': None},
#                'type': 'Feature'}],
#  'name': 'amenity',
#  'type': 'FeatureCollection'}

# %%
# Ray-casting algorithm to determine if a point is inside a polygon
def is_point_inside_polygon(point, polygon):
    x, y = point
    oddNodes = False
    j = len(polygon) - 1

    for i in range(len(polygon)):
        xi, yi = polygon[i]
        xj, yj = polygon[j]
        if yi < y and yj >= y or yj < y and yi >= y:
            if xi + (y - yi) / (yj - yi) * (xj - xi) < x:
                oddNodes = not oddNodes
        j = i
    return oddNodes

anchor_structure_new = {'features' : []}
amenity_structure_new = {'features' : []}

import copy

for anchor_feature in anchor_structure['features']:
    point = tuple(anchor_feature['geometry']['coordinates'])

    for unit_feature in unit_structure['features']:
        polygon = unit_feature['geometry']['coordinates'][0][0]
        if is_point_inside_polygon(point, polygon):
            new_anchor_feature = copy.deepcopy(anchor_feature)  # Create a deep copy
            new_anchor_feature['properties']['unit_id'] = unit_feature['id']
            anchor_structure_new['features'].append(new_anchor_feature)
            break


for amenity_feature in amenity_structure['features']:
    point = tuple(amenity_feature['geometry']['coordinates'])

    for unit_feature in unit_structure['features']:
        polygon = unit_feature['geometry']['coordinates'][0][0]
        if is_point_inside_polygon(point, polygon):
            new_amenity_feature = copy.deepcopy(amenity_feature)  # Create a deep copy
            new_amenity_feature['properties']['unit_ids'] = [unit_feature['id']]
            amenity_structure_new['features'].append(new_amenity_feature)
            break

# %%
anchor_structure = anchor_structure_new
anchor_structure["type"] = "FeatureCollection"
anchor_structure["name"] = "anchor"
pprint(anchor_structure)

amenity_structure = amenity_structure_new
amenity_structure["type"] = "FeatureCollection"
amenity_structure["name"] = "amenity"
pprint(amenity_structure)
# Out:
# {'features': [{'feature_type': 'anchor',
#                'geometry': {'coordinates': [0.194148119344427,
#                                             52.18563022680937],
#                             'type': 'Point'},
#                'id': 'b2b925cd-80f8-4c26-a045-601ca597bfb7',
#                'properties': {'address_id': 'e6fcbe2d-a0a8-4f4f-80fa-438694e1d185',
#                               'unit_id': 'b3322898-1fba-4f56-abb7-26e336823c84'},
#                'type': 'Feature'},
#               {'feature_type': 'anchor',
#                'geometry': {'coordinates': [0.19411484936688,
#                                             52.18576957327999],
#                             'type': 'Point'},
#                'id': '31cb41b8-0908-4b2d-8727-46957da7ebe2',
#                'properties': {'address_id': 'e6fcbe2d-a0a8-4f4f-80fa-438694e1d185',
#                               'unit_id': 'd3502288-f529-4c8a-a2c6-b6ef5ac78bff'},
#                'type': 'Feature'},
#               {'feature_type': 'anchor',
#                'geometry': {'coordinates': [0.194553089635824,
#                                             52.18559412410751],
#                             'type': 'Point'},
#                'id': '448cfab7-5fc5-45e9-be40-54e87d9725e7',
#                'properties': {'address_id': 'e6fcbe2d-a0a8-4f4f-80fa-438694e1d185',
#                               'unit_id': 'd0a1ccac-8685-4649-805b-04728fc48561'},
#                'type': 'Feature'},
#               {'feature_type': 'anchor',
#                'geometry': {'coordinates': [0.19458723822821,
#                                             52.185771666941406],
#                             'type': 'Point'},
#                'id': 'e8ffecb8-f3ee-4c15-b1b8-ff6bc4b64980',
#                'properties': {'address_id': 'e6fcbe2d-a0a8-4f4f-80fa-438694e1d185',
#                               'unit_id': 'd91ff069-6fd7-4684-bccf-4e9e74d47a32'},
#                'type': 'Feature'}],
#  'name': 'anchor',
#  'type': 'FeatureCollection'}
# {'features': [{'feature_type': 'amenity',
#                'geometry': {'coordinates': [0.194257852974217,
#                                             52.185638878340924],
#                             'type': 'Point'},
#                'id': 'd56836d6-ae07-41d7-a889-56a93f7f99a0',
#                'properties': {'accessibility': None,
#                               'address_id': 'e6fcbe2d-a0a8-4f4f-80fa-438694e1d185',
#                               'alt_name': None,
#                               'category': 'restroom',
#                               'correlation_id': None,
#                               'hours': None,
#                               'name': None,
#                               'phone': None,
#                               'unit_ids': ['869da682-bf6d-4aaf-b503-480d90cffb4c'],
#                               'website': None},
#                'type': 'Feature'},
#               {'feature_type': 'amenity',
#                'geometry': {'coordinates': [0.194263281915114,
#                                             52.185746682575996],
#                             'type': 'Point'},
#                'id': 'f87ac44b-058f-4b91-a041-222c92364ad3',
#                'properties': {'accessibility': None,
#                               'address_id': 'e6fcbe2d-a0a8-4f4f-80fa-438694e1d185',
#                               'alt_name': None,
#                               'category': 'restroom',
#                               'correlation_id': None,
#                               'hours': None,
#                               'name': None,
#                               'phone': None,
#                               'unit_ids': ['d02a1df0-5b60-473e-b7e5-51c2df72ede0'],
#                               'website': None},
#                'type': 'Feature'},
#               {'feature_type': 'amenity',
#                'geometry': {'coordinates': [0.194259639398593,
#                                             52.18579860537545],
#                             'type': 'Point'},
#                'id': '639a8e58-b928-4dde-8ad7-5ffb21287a49',
#                'properties': {'accessibility': None,
#                               'address_id': 'e6fcbe2d-a0a8-4f4f-80fa-438694e1d185',
#                               'alt_name': None,
#                               'category': 'restroom',
#                               'correlation_id': None,
#                               'hours': None,
#                               'name': None,
#                               'phone': None,
#                               'unit_ids': ['de8003ab-772f-4f14-a930-89d42f7e1f16'],
#                               'website': None},
#                'type': 'Feature'},
#               {'feature_type': 'amenity',
#                'geometry': {'coordinates': [0.194426056872151,
#                                             52.185800001148756],
#                             'type': 'Point'},
#                'id': 'f214f4cf-ed1d-4a80-aeeb-b5ea1bac63bb',
#                'properties': {'accessibility': None,
#                               'address_id': 'e6fcbe2d-a0a8-4f4f-80fa-438694e1d185',
#                               'alt_name': None,
#                               'category': 'restroom',
#                               'correlation_id': None,
#                               'hours': None,
#                               'name': None,
#                               'phone': None,
#                               'unit_ids': ['16ca6ad4-dd6a-4e96-bc6b-4c766c449ccf'],
#                               'website': None},
#                'type': 'Feature'},
#               {'feature_type': 'amenity',
#                'geometry': {'coordinates': [0.194434252534323,
#                                             52.18574472849093],
#                             'type': 'Point'},
#                'id': '828bd436-e471-4cf3-84e4-0b39d2603df6',
#                'properties': {'accessibility': None,
#                               'address_id': 'e6fcbe2d-a0a8-4f4f-80fa-438694e1d185',
#                               'alt_name': None,
#                               'category': 'restroom',
#                               'correlation_id': None,
#                               'hours': None,
#                               'name': None,
#                               'phone': None,
#                               'unit_ids': ['41ebc079-545f-47f7-9d18-79713d5bf409'],
#                               'website': None},
#                'type': 'Feature'}],
#  'name': 'amenity',
#  'type': 'FeatureCollection'}

# %%
import json


def compute_polygon_centroid(polygon):
    """
    Compute the centroid of a polygon.
    """
    area = 0.0
    x_centroid = 0.0
    y_centroid = 0.0
    
    for i in range(-1, len(polygon)-1):
        xi, yi = polygon[i]
        xi1, yi1 = polygon[i+1]
        
        fi = xi * yi1 - xi1 * yi
        area += fi
        x_centroid += (xi + xi1) * fi
        y_centroid += (yi + yi1) * fi
    
    area /= 2.0
    x_centroid /= (6.0 * area)
    y_centroid /= (6.0 * area)
    
    return [x_centroid, y_centroid]


def update_unit_display_point():
    """
    Update the display_point for each unit with the centroid of the unit polygon.
    """

    for unit in unit_structure['features']:
        polygon = unit['geometry']['coordinates'][0][0]
        centroid = compute_polygon_centroid(polygon)
        
        unit['properties']['display_point'] = {
            "coordinates": centroid,
            "type": "Point"
        }

update_unit_display_point()
# Iterate through each feature and update the "name" property
for feature in unit_structure["features"]:
    feature["properties"]["name"] = {"en": "input name here"}
pprint(unit_structure)
# Out:
# {'features': [{'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194283250799545,
#                                                52.18557310736924],
#                                               [0.194232308491778,
#                                                52.18557241003945],
#                                               [0.194231581481576,
#                                                52.18560182450015],
#                                               [0.194282067071084,
#                                                52.18560200544564],
#                                               [0.194283250799545,
#                                                52.18557310736924]]]],
#                             'type': 'MultiPolygon'},
#                'id': 'c833b87f-80d2-4d87-983e-3252523403a7',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'display_point': {'coordinates': [0.1945757887714961,
#                                                                 52.18577698577574],
#                                                 'type': 'Point'},
#                               'level_id': '0bb161a4-d929-4d2d-88b8-107d96baf8c0',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194232308491778,
#                                                52.18557241003945],
#                                               [0.194147258747965,
#                                                52.18557140518274],
#                                               [0.19414607324852,
#                                                52.18559218952964],
#                                               [0.194231810319444,
#                                                52.18559256583923],
#                                               [0.194232308491778,
#                                                52.18557241003945]]]],
#                             'type': 'MultiPolygon'},
#                'id': 'd32ebe44-f48a-43d7-a5b1-34d9e7fbfa5c',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'display_point': {'coordinates': [0.1945757887714961,
#                                                                 52.18577698577574],
#                                                 'type': 'Point'},
#                               'level_id': '0bb161a4-d929-4d2d-88b8-107d96baf8c0',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194146678811163,
#                                                52.18557139792483],
#                                               [0.194089819610152,
#                                                52.1855706863312],
#                                               [0.194038717222795,
#                                                52.185570340074925],
#                                               [0.194038604466883,
#                                                52.18559963345006],
#                                               [0.194145466162433,
#                                                52.18560019200002],
#                                               [0.19414607324852,
#                                                52.18559218952964],
#                                               [0.194146678811163,
#                                                52.18557139792483]]]],
#                             'type': 'MultiPolygon'},
#                'id': 'a14b1c03-7e36-4b36-bd0c-60513c1e995f',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'display_point': {'coordinates': [0.1945757887714961,
#                                                                 52.18577698577574],
#                                                 'type': 'Point'},
#                               'level_id': '0bb161a4-d929-4d2d-88b8-107d96baf8c0',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194069886849902,
#                                                52.18559979695835],
#                                               [0.194038604466883,
#                                                52.18559963345006],
#                                               [0.194038006551374,
#                                                52.18561336124907],
#                                               [0.194069276858547,
#                                                52.18561340537819],
#                                               [0.194069886849902,
#                                                52.18559979695835]]]],
#                             'type': 'MultiPolygon'},
#                'id': 'f1537975-b88c-4ad4-862b-ca594e6b98fa',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'display_point': {'coordinates': [0.1945757887714961,
#                                                                 52.18577698577574],
#                                                 'type': 'Point'},
#                               'level_id': '0bb161a4-d929-4d2d-88b8-107d96baf8c0',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194037558702104,
#                                                52.18562364361006],
#                                               [0.194035313705211,
#                                                52.18567518740834],
#                                               [0.194090524871573,
#                                                52.185675750137676],
#                                               [0.194093256758973,
#                                                52.1856245716102],
#                                               [0.194037558702104,
#                                                52.18562364361006]]]],
#                             'type': 'MultiPolygon'},
#                'id': 'ef02c343-ff86-4cf7-85cf-5645bec55a4f',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'display_point': {'coordinates': [0.1945757887714961,
#                                                                 52.18577698577574],
#                                                 'type': 'Point'},
#                               'level_id': '0bb161a4-d929-4d2d-88b8-107d96baf8c0',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194280082778044,
#                                                52.18564576372339],
#                                               [0.194228712842049,
#                                                52.185645578076596],
#                                               [0.194231806940102,
#                                                52.185592702565636],
#                                               [0.194146301708928,
#                                                52.185592190532375],
#                                               [0.194145466162433,
#                                                52.18560019200002],
#                                               [0.194069868924426,
#                                                52.185600196861444],
#                                               [0.194069276858547,
#                                                52.18561340537819],
#                                               [0.194038006551374,
#                                                52.18561336124907],
#                                               [0.194037542934714,
#                                                52.185624005620205],
#                                               [0.194093243803826,
#                                                52.18562493962979],
#                                               [0.194091448879848,
#                                                52.185675928385116],
#                                               [0.194278114472344,
#                                                52.18567761117395],
#                                               [0.194280105317845,
#                                                52.185649897211306],
#                                               [0.194280082778044,
#                                                52.18564576372339]]]],
#                             'type': 'MultiPolygon'},
#                'id': 'b3322898-1fba-4f56-abb7-26e336823c84',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'display_point': {'coordinates': [0.1945757887714961,
#                                                                 52.18577698577574],
#                                                 'type': 'Point'},
#                               'level_id': '0bb161a4-d929-4d2d-88b8-107d96baf8c0',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194282044215818,
#                                                52.18560256340554],
#                                               [0.194231581481576,
#                                                52.18560182450015],
#                                               [0.194229319928131,
#                                                52.18563234144495],
#                                               [0.194280824502974,
#                                                52.185632339939936],
#                                               [0.194282044215818,
#                                                52.18560256340554]]]],
#                             'type': 'MultiPolygon'},
#                'id': 'e61cd77c-6aa1-41b3-9435-07e855197761',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'display_point': {'coordinates': [0.1945757887714961,
#                                                                 52.18577698577574],
#                                                 'type': 'Point'},
#                               'level_id': '0bb161a4-d929-4d2d-88b8-107d96baf8c0',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194280824502974,
#                                                52.185632339939936],
#                                               [0.194229475345016,
#                                                52.18563254755354],
#                                               [0.194228723523121,
#                                                52.185645395546224],
#                                               [0.194280082778044,
#                                                52.18564576372339],
#                                               [0.194280824502974,
#                                                52.185632339939936]]]],
#                             'type': 'MultiPolygon'},
#                'id': '869da682-bf6d-4aaf-b503-480d90cffb4c',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'display_point': {'coordinates': [0.1945757887714961,
#                                                                 52.18577698577574],
#                                                 'type': 'Point'},
#                               'level_id': '0bb161a4-d929-4d2d-88b8-107d96baf8c0',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.

#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'display_point': {'coordinates': [0.1945757887714961,
#                                                                 52.18577698577574],
#                                                 'type': 'Point'},
#                               'level_id': '0bb161a4-d929-4d2d-88b8-107d96baf8c0',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'}],
#  'name': 'unit',
#  'type': 'FeatureCollection'}

# %%
## Transform opening.geojson by setting its display point as the centre of the line

import json

def compute_line_center(coordinates):
    """
    Compute the center of a line given its coordinates.
    """
    x_coords = [coord[0] for coord in coordinates[0]]
    y_coords = [coord[1] for coord in coordinates[0]]
    
    return [sum(x_coords) / len(x_coords), sum(y_coords) / len(y_coords)]

def update_openings():
    """
    Update the display_point and category for each opening.
    """


    for opening in opening_structure['features']:
        center = compute_line_center(opening['geometry']['coordinates'])
        opening['properties']['display_point'] = {
            "coordinates": center,
            "type": "Point"
        }
        opening['properties']['category'] = "pedestrian"

# Sample usage:
update_openings()

# %%
## generate occupant.geojson that references the UUID

import json
import os
import uuid


# Generate features for the occupant.geojson
for feature in anchor_structure["features"]:
    occupant_feature = {
        "geometry": None,
        "feature_type": "occupant",
        "id": str(uuid.uuid4()),  
        "properties": {
            "alt_name": None,
            "category": None,
            "hours": "",
            "name": {
                "en": "Test"
            },
            "anchor_id": feature["id"],
            "phone": "",
            "restriction": None,
            "website": None,
            "correlation_id": None
        },
        "type": "Feature"
    }
    occupant_structure["features"].append(occupant_feature)

 # Remove the sample feature
occupant_structure["features"].pop(0)

from pprint import pprint
pprint(occupant_structure)
# Out:
# {'features': [{'feature_type': 'occupant',
#                'geometry': None,
#                'id': '64c293ab-d4bf-41b9-92f8-86cf964bf0a8',
#                'properties': {'alt_name': None,
#                               'anchor_id': 'b2b925cd-80f8-4c26-a045-601ca597bfb7',
#                               'category': None,
#                               'correlation_id': None,
#                               'hours': '',
#                               'name': {'en': 'Test'},
#                               'phone': '',
#                               'restriction': None,
#                               'website': None},
#                'type': 'Feature'},
#               {'feature_type': 'occupant',
#                'geometry': None,
#                'id': '37be16c6-a97d-4472-b8ed-1b6fb8f6e15d',
#                'properties': {'alt_name': None,
#                               'anchor_id': '31cb41b8-0908-4b2d-8727-46957da7ebe2',
#                               'category': None,
#                               'correlation_id': None,
#                               'hours': '',
#                               'name': {'en': 'Test'},
#                               'phone': '',
#                               'restriction': None,
#                               'website': None},
#                'type': 'Feature'},
#               {'feature_type': 'occupant',
#                'geometry': None,
#                'id': '4d0addbc-cd4e-417d-8882-27bfc9ee4d1e',
#                'properties': {'alt_name': None,
#                               'anchor_id': '448cfab7-5fc5-45e9-be40-54e87d9725e7',
#                               'category': None,
#                               'correlation_id': None,
#                               'hours': '',
#                               'name': {'en': 'Test'},
#                               'phone': '',
#                               'restriction': None,
#                               'website': None},
#                'type': 'Feature'},
#               {'feature_type': 'occupant',
#                'geometry': None,
#                'id': 'dcc8ae2a-6b43-463c-a9b2-7f38ca75aa8d',
#                'properties': {'alt_name': None,
#                               'anchor_id': 'e8ffecb8-f3ee-4c15-b1b8-ff6bc4b64980',
#                               'category': None,
#                               'correlation_id': None,
#                               'hours': '',
#                               'name': {'en': 'Test'},
#                               'phone': '',
#                               'restriction': None,
#                               'website': None},
#                'type': 'Feature'}],
#  'name': 'occupant',
#  'type': 'FeatureCollection'}

# %%
import json
import os

# List of your 10 structures (dictionaries)
structures = [address_structure, amenity_structure, anchor_structure, building_structure, footprint_structure, level_structure, occupant_structure, opening_structure, unit_structure, venue_structure]

# Specify the base directory where you want to save the GeoJSON files
base_directory = "C:\\Users\\amosk\\GitHub\\Geojson_2_IMDF_Transformer\\IMDF"

# Loop through the structures and save each one to a separate GeoJSON file
for structure_name, structure in zip(["address", "amenity", "anchor", "building", "footprint", "level", "occupant", "opening", "unit", "venue"], structures):
    # Generate the file name
    geojson_file_name = f"{structure_name}.geojson"
    
    # Construct the full file path
    file_path = os.path.join(base_directory, geojson_file_name)
    
    # Save the structure to the GeoJSON file
    with open(file_path, "w") as geojson_file:
        json.dump(structure, geojson_file, indent=2)

# %%
import random

# Given dictionary
structure = {'features': [{'name': 'xxx'}, {'name': 'yyy'}, {'name':'zzz'}]}

# Iterate through the 'features' list and append a random number to 'name'
for feature in structure['features']:
    feature['name'] = str(random.randint(1, 10000))  # Appending a random number between 1 and 10000

print(structure)
# Out:
# {'features': [{'name': '5970'}, {'name': '7816'}, {'name': '6214'}]}
