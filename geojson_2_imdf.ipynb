# %%
## initialize dictionaries with some predefined values

address_structure = {
    "type": "FeatureCollection",
    "name": "address",
    "features": [
        {
            "geometry": None,
            "feature_type":"address",
            "id": "",
            "properties": {
                "address": "CPC4, Capital Park, Fulbourn, Cambridge",
                "country": "GB",
                "locality": "Cambridge",
                "postal_code": "CB21 5XE",
                "postal_code_ext": None,
                "province": "GB-CAM",
                "unit": None
            },
            "type": "Feature"
        }
    ]
}

amenity_structure = {
    "type": "FeatureCollection",
   "name": "amenity",
    "features": [
        {
            "geometry": {
                "type": "Point",
                "coordinates": []
            },
            "type": "Feature",
            "feature_type":"amenity",
            "id": "",
            "properties": {
                "accessibility": None,
                "address_id": "",
                "alt_name": None,
                "category": "restroom",
                "correlation_id": None,
                "hours": None,
                "name": None,
                "phone": None,
                "unit_ids": [],
                "website": None
            }
        }
    ]
}

anchor_structure = {
    "type": "FeatureCollection",
   "name": "anchor",
    "features": [
        {
            "geometry": {
                "type": "Point",
                "coordinates": []
            },
            "feature_type":"anchor",
            "id": "",
            "properties": {
                "address_id": "",
                "unit_id": ""
            },
            "type": "Feature"
        }
    ]
}

building_structure = {
    "type": "FeatureCollection",
   "name": "building",
        "features": [
        {
            "geometry": None,
            "feature_type":"building",
            "id": "",
            "properties": {
                "address_id": "",
                "alt_name": None,
                "category": "unspecified",
                "display_point": {
                    "coordinates": [],
                    "type":"Point"
                },
                "name": {
                    "en": "CPC4"
                },
                "restriction": None
            },
            "type": "Feature"
        }
    ]
}

footprint_structure = {
    "type": "FeatureCollection",
    "name": "footprint",
     "features": [
        {
            "geometry": {
                "type": "MultiPolygon",
                "coordinates": []
            },
            "feature_type":"footprint",
            "id": "",
            "properties": {
                "building_ids": [],
                "category": "ground",
                "name": None
            },
            "type": "Feature"
        }
    ]
}

level_structure = {
    "type": "FeatureCollection",
   "name": "level",
    "features": [
        {
            "geometry": {
                "type": "MultiPolygon",
                "coordinates": []
            },
            "feature_type":"level",
            "id": "",
            "properties": {
                "address_id": "",
                "building_ids": [],
                "category": "unspecified",
                "display_point": {
                    "coordinates": [],
                    "type":"Point"
                },
                "name": {
                    "en": "Ground Floor"
                },
                "ordinal": 0,
                "outdoor": False,
                "restriction": None,
                "short_name": {
                    "en": "G"
                }
            },
            "type": "Feature"
        }
    ]
}

occupant_structure = {
    "type": "FeatureCollection",
   "name": "occupant",
    "features": [
        {
            "geometry": None,
            "feature_type": "occupant",
            "id": "",
            "properties": {
                "alt_name": None,
                "anchor_id": "",
                "category": "",
                "hours": "",
                "name": {
                    "en": ""
                },
                "phone": "",
                "restriction": None,
                "website": None,
                "correlation_id": None
            },
            "type": "Feature"
        }
    ]
}

opening_structure = {
    "type": "FeatureCollection",
   "name": "opening",
    "features": [
        {
            "geometry": {
                "type": "MultiLineString",
                "coordinates": []
            },
            "type":"Feature",
            "feature_type": "opening",
            "id": "",
            "properties": {
                "access_control": None,
                "accessibility": None,
                "alt_name": None,
                "category": "",
                "display_point": {
                    "coordinates": [],
                    "type":"Feature"
                },
                "door": None,
                "level_id": "",
                "name": None
            }
        }
    ]
}


unit_structure = {
    "type": "FeatureCollection",
   "name": "unit",
    "features": [
        {
            "geometry": {
                "type": "MultiPolygon",
                "coordinates": []
            }, 
            "type":"Feature",
            "feature_type": "unit",
            "id": "",
            "properties": {
                "accessibility": None,
                "alt_name": None,
                "category": "office",
                "level_id": "",
                "name": None,
                "restriction": None
            }
        }
    ]
}

venue_structure = {
    "type": "FeatureCollection",
   "name": "venue",
    "features": [
        {
            "geometry": {
                "type": "MultiPolygon",
                "coordinates": []
            },
            "feature_type":"venue",
            "id": "",
            "properties": {
                "address_id": "",
                "alt_name": None,
                "category": "businesscampus",
                "display_point": {
                    "coordinates": [],
                    "type":"Point"
                },
                "hours": "",
                "name": {
                    "en": "CPC4"
                },
                "phone": None,
                "restriction": None,
                "website": ""
            },
            "type":"Feature"
        }
    ]
}

# %%
import os
import json

## Copy the coordinates over
# Your folder path
folder_path = "C:\\Users\\amosk\\GitHub\\Geojson_2_IMDF_Transformer\\CPC4_QGIS_Geojsons"

# Map each structure to its name
structures = {
    "address": address_structure,
    "amenity": amenity_structure,
    "anchor": anchor_structure,
    "building": building_structure,
    "footprint": footprint_structure,
    "level": level_structure,
    "occupant": occupant_structure,
    "opening": opening_structure,
    "unit": unit_structure,
    "venue": venue_structure,
}

# Iterate through the files in your folder. Only features with point,line, or polygon geometries should be included, since QGIS was used
# primarily to create geo-referenceed features. (i.e amenity, anchor, footprint, level, opening, unit, venue). Features that have null 
# geometry (ie occupant, building, address) are created manually by 'structures'.
for file_name in os.listdir(folder_path):
    # Check if the file has the .geojson extension
    if not file_name.endswith('.geojson'):
        continue

    # Extract feature type from the file name
    feature_type = file_name.split('.')[0]
    
    # If the structure doesn't exist for this file, skip it
    if feature_type not in structures:
        print(f"No structure found for {feature_type}. Skipping...")
        continue
    
    # Read the geojson file
    with open(os.path.join(folder_path, file_name), 'r') as file:
        geojson_data = json.load(file)

    # Iterate through features in the geojson file
    for feature in geojson_data.get("features", []):
        # Create a new feature based on the sample structure
        new_feature = structures[feature_type]["features"][0].copy()
        
        # Preserve existing properties in the sample structure. Copy properties from QGIS Geojson to the structures. 
        # Properties can be defined using QGIS shapefile fields, but it may be easier to configure properties after transformation using IMDF sandbox.
        for key in new_feature["properties"]:
            if key not in feature["properties"]:
                continue
            new_feature["properties"][key] = feature["properties"][key]
        
        # Copy geometry from the geojson feature
        new_feature["geometry"] = feature["geometry"]
        
        # Append the new feature to the structure
        structures[feature_type]["features"].append(new_feature)

    # Remove the sample feature
    structures[feature_type]["features"].pop(0)


from pprint import pprint
# pprint(footprint_structure)
# Out:
# No structure found for amenity2. Skipping...
# No structure found for anchor2. Skipping...
# No structure found for level2. Skipping...
# No structure found for opening2. Skipping...
# No structure found for unit2. Skipping...

# %%
## add UUID

import uuid

def generate_uuid_for_structures(structures):
    for structure in structures.values():
        for feature in structure['features']:
            feature['id'] = str(uuid.uuid4())
    return structures

structures = generate_uuid_for_structures(structures)

# %%
import json

# Extract UUID from the given structure based on the feature type.
def get_uuid_from_structure(structure, feature_type):
    for feature in structure.get('features', []):
        if feature.get('feature_type') == feature_type:
            return feature.get('id')
    return None

# Update the address_id, building_ids, and level_id in the given structure with the provided UUIDs.
def update_ids_in_structure(structure, address_uuid, building_uuid, level_uuid):
    for feature in structure.get('features', []):
        # Only replace the keys if they already exist in the properties
        if 'address_id' in feature['properties']:
            feature['properties']['address_id'] = address_uuid
        if 'building_ids' in feature['properties']:
            feature['properties']['building_ids'] = [building_uuid]
        if 'level_id' in feature['properties']:
            feature['properties']['level_id'] = level_uuid

def main():
    # Extract UUIDs from address, building, and level structures
    address_uuid = get_uuid_from_structure(address_structure, 'address')
    building_uuid = get_uuid_from_structure(building_structure, 'building')
    level_uuid = get_uuid_from_structure(level_structure, 'level')

    # List of structures that need to be updated
    structures_to_update = [level_structure, venue_structure, opening_structure, unit_structure, 
                            anchor_structure, amenity_structure, footprint_structure, building_structure]

    for struct in structures_to_update:
        update_ids_in_structure(struct, address_uuid, building_uuid, level_uuid)
        # print(f"Updated IDs in {struct['features'][0]['feature_type']} structure")

main()

# %%
# Ray-casting algorithm to determine if a point is inside a polygon
def is_point_inside_polygon(point, polygon):
    x, y = point
    oddNodes = False
    j = len(polygon) - 1

    for i in range(len(polygon)):
        xi, yi = polygon[i]
        xj, yj = polygon[j]
        if yi < y and yj >= y or yj < y and yi >= y:
            if xi + (y - yi) / (yj - yi) * (xj - xi) < x:
                oddNodes = not oddNodes
        j = i
    return oddNodes

anchor_structure_new = {'features' : []}
amenity_structure_new = {'features' : []}

import copy

for anchor_feature in anchor_structure['features']:
    point = tuple(anchor_feature['geometry']['coordinates'])

    for unit_feature in unit_structure['features']:
        polygon = unit_feature['geometry']['coordinates'][0][0]
        if is_point_inside_polygon(point, polygon):
            new_anchor_feature = copy.deepcopy(anchor_feature)  # Create a deep copy
            new_anchor_feature['properties']['unit_id'] = unit_feature['id']
            anchor_structure_new['features'].append(new_anchor_feature)
            break


for amenity_feature in amenity_structure['features']:
    point = tuple(amenity_feature['geometry']['coordinates'])

    for unit_feature in unit_structure['features']:
        polygon = unit_feature['geometry']['coordinates'][0][0]
        if is_point_inside_polygon(point, polygon):
            new_amenity_feature = copy.deepcopy(amenity_feature)  # Create a deep copy
            new_amenity_feature['properties']['unit_ids'] = [unit_feature['id']]
            amenity_structure_new['features'].append(new_amenity_feature)
            break

# %%
anchor_structure = anchor_structure_new
anchor_structure["type"] = "FeatureCollection"
anchor_structure["name"] = "anchor"
pprint(anchor_structure)

amenity_structure = amenity_structure_new
amenity_structure["type"] = "FeatureCollection"
amenity_structure["name"] = "amenity"
pprint(amenity_structure)
# Out:
# {'features': [{'feature_type': 'anchor',
#                'geometry': {'coordinates': [0.194148119344427,
#                                             52.18563022680937],
#                             'type': 'Point'},
#                'id': '34f0d545-4646-4470-8e1a-a4ad7c15a031',
#                'properties': {'address_id': '427674b4-a321-4e4a-86fa-1f01449581c9',
#                               'unit_id': '233465e3-ba67-4633-bc0f-f8275c3af693'},
#                'type': 'Feature'},
#               {'feature_type': 'anchor',
#                'geometry': {'coordinates': [0.19411484936688,
#                                             52.18576957327999],
#                             'type': 'Point'},
#                'id': '0215c4a4-2fa1-469b-8cc9-4c5994684694',
#                'properties': {'address_id': '427674b4-a321-4e4a-86fa-1f01449581c9',
#                               'unit_id': '1261d53f-cf96-4555-9aee-a29cbc2cf7fa'},
#                'type': 'Feature'},
#               {'feature_type': 'anchor',
#                'geometry': {'coordinates': [0.194553089635824,
#                                             52.18559412410751],
#                             'type': 'Point'},
#                'id': '9368774d-ac79-4219-996e-379af0b2a95f',
#                'properties': {'address_id': '427674b4-a321-4e4a-86fa-1f01449581c9',
#                               'unit_id': 'd85cc155-2260-43aa-9ed7-8e8bc63c147f'},
#                'type': 'Feature'},
#               {'feature_type': 'anchor',
#                'geometry': {'coordinates': [0.19458723822821,
#                                             52.185771666941406],
#                             'type': 'Point'},
#                'id': '5bf69137-409b-44f2-b1e8-2ad71c006162',
#                'properties': {'address_id': '427674b4-a321-4e4a-86fa-1f01449581c9',
#                               'unit_id': '08edb4b2-166d-42ee-a828-7e0118ab8b12'},
#                'type': 'Feature'}],
#  'name': 'anchor',
#  'type': 'FeatureCollection'}
# {'features': [{'feature_type': 'amenity',
#                'geometry': {'coordinates': [0.194257852974217,
#                                             52.185638878340924],
#                             'type': 'Point'},
#                'id': 'e268e0d0-28b8-44a5-b056-cb1e891b2de4',
#                'properties': {'accessibility': None,
#                               'address_id': '427674b4-a321-4e4a-86fa-1f01449581c9',
#                               'alt_name': None,
#                               'category': 'restroom',
#                               'correlation_id': None,
#                               'hours': None,
#                               'name': None,
#                               'phone': None,
#                               'unit_ids': ['4637c2bc-1509-48df-999f-1f2432d0fc60'],
#                               'website': None},
#                'type': 'Feature'},
#               {'feature_type': 'amenity',
#                'geometry': {'coordinates': [0.194263281915114,
#                                             52.185746682575996],
#                             'type': 'Point'},
#                'id': '9050d7cf-6e39-47d9-8e68-b057ef72a00f',
#                'properties': {'accessibility': None,
#                               'address_id': '427674b4-a321-4e4a-86fa-1f01449581c9',
#                               'alt_name': None,
#                               'category': 'restroom',
#                               'correlation_id': None,
#                               'hours': None,
#                               'name': None,
#                               'phone': None,
#                               'unit_ids': ['ce281d2d-06bc-4378-9e7b-0cc5e042bbdb'],
#                               'website': None},
#                'type': 'Feature'},
#               {'feature_type': 'amenity',
#                'geometry': {'coordinates': [0.194259639398593,
#                                             52.18579860537545],
#                             'type': 'Point'},
#                'id': 'ad3a8d27-7e9b-41c7-bec2-9200f43110a1',
#                'properties': {'accessibility': None,
#                               'address_id': '427674b4-a321-4e4a-86fa-1f01449581c9',
#                               'alt_name': None,
#                               'category': 'restroom',
#                               'correlation_id': None,
#                               'hours': None,
#                               'name': None,
#                               'phone': None,
#                               'unit_ids': ['efb1bccb-ab7f-4d59-b47c-eda691e2ff6f'],
#                               'website': None},
#                'type': 'Feature'},
#               {'feature_type': 'amenity',
#                'geometry': {'coordinates': [0.194426056872151,
#                                             52.185800001148756],
#                             'type': 'Point'},
#                'id': '6959948c-225a-468e-9245-3cc85613ad88',
#                'properties': {'accessibility': None,
#                               'address_id': '427674b4-a321-4e4a-86fa-1f01449581c9',
#                               'alt_name': None,
#                               'category': 'restroom',
#                               'correlation_id': None,
#                               'hours': None,
#                               'name': None,
#                               'phone': None,
#                               'unit_ids': ['cc64961d-0696-407a-bc26-842d23ab3680'],
#                               'website': None},
#                'type': 'Feature'},
#               {'feature_type': 'amenity',
#                'geometry': {'coordinates': [0.194434252534323,
#                                             52.18574472849093],
#                             'type': 'Point'},
#                'id': '8684f443-a42d-40da-bc3b-e8d1bba55fc1',
#                'properties': {'accessibility': None,
#                               'address_id': '427674b4-a321-4e4a-86fa-1f01449581c9',
#                               'alt_name': None,
#                               'category': 'restroom',
#                               'correlation_id': None,
#                               'hours': None,
#                               'name': None,
#                               'phone': None,
#                               'unit_ids': ['d2f0397c-c549-4ff1-904e-0f063f1dd222'],
#                               'website': None},
#                'type': 'Feature'}],
#  'name': 'amenity',
#  'type': 'FeatureCollection'}

# %%
import json


# def compute_polygon_centroid(polygon):
#     """
#     Compute the centroid of a polygon.
#     """
#     area = 0.0
#     x_centroid = 0.0
#     y_centroid = 0.0
    
#     for i in range(-1, len(polygon)-1):
#         xi, yi = polygon[i]
#         xi1, yi1 = polygon[i+1]
        
#         fi = xi * yi1 - xi1 * yi
#         area += fi
#         x_centroid += (xi + xi1) * fi
#         y_centroid += (yi + yi1) * fi
    
#     area /= 2.0
#     x_centroid /= (6.0 * area)
#     y_centroid /= (6.0 * area)
    
#     return [x_centroid, y_centroid]


# def update_unit_display_point():
#     """
#     Update the display_point for each unit with the centroid of the unit polygon.
#     """

#     for unit in unit_structure['features']:
#         polygon = unit['geometry']['coordinates'][0][0]
#         centroid = compute_polygon_centroid(polygon)
        
#         unit['properties']['display_point'] = {
#             "coordinates": centroid,
#             "type": "Point"
#         }

# update_unit_display_point()
# Iterate through each feature and update the "name" property
for feature in unit_structure["features"]:
    feature["properties"]["name"] = {"en": "input name here"}
pprint(unit_structure)
# Out:
# {'features': [{'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194283250799545,
#                                                52.18557310736924],
#                                               [0.194232308491778,
#                                                52.18557241003945],
#                                               [0.194231581481576,
#                                                52.18560182450015],
#                                               [0.194282067071084,
#                                                52.18560200544564],
#                                               [0.194283250799545,
#                                                52.18557310736924]]]],
#                             'type': 'MultiPolygon'},
#                'id': 'cd620b99-aa07-4488-ac2a-22a24700fd26',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'level_id': '227dbfdb-5ef2-4a9f-b295-c8eab93dc4db',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194232308491778,
#                                                52.18557241003945],
#                                               [0.194147258747965,
#                                                52.18557140518274],
#                                               [0.19414607324852,
#                                                52.18559218952964],
#                                               [0.194231810319444,
#                                                52.18559256583923],
#                                               [0.194232308491778,
#                                                52.18557241003945]]]],
#                             'type': 'MultiPolygon'},
#                'id': 'e510bdce-13bf-4838-9778-a02bb6183e35',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'level_id': '227dbfdb-5ef2-4a9f-b295-c8eab93dc4db',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194146678811163,
#                                                52.18557139792483],
#                                               [0.194089819610152,
#                                                52.1855706863312],
#                                               [0.194038717222795,
#                                                52.185570340074925],
#                                               [0.194038604466883,
#                                                52.18559963345006],
#                                               [0.194145466162433,
#                                                52.18560019200002],
#                                               [0.19414607324852,
#                                                52.18559218952964],
#                                               [0.194146678811163,
#                                                52.18557139792483]]]],
#                             'type': 'MultiPolygon'},
#                'id': 'e640c126-874f-4742-a884-0bd24c918b6e',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'level_id': '227dbfdb-5ef2-4a9f-b295-c8eab93dc4db',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194069886849902,
#                                                52.18559979695835],
#                                               [0.194038604466883,
#                                                52.18559963345006],
#                                               [0.194038006551374,
#                                                52.18561336124907],
#                                               [0.194069276858547,
#                                                52.18561340537819],
#                                               [0.194069886849902,
#                                                52.18559979695835]]]],
#                             'type': 'MultiPolygon'},
#                'id': '1337cbbf-b003-461d-9033-1ec14b2ac88d',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'level_id': '227dbfdb-5ef2-4a9f-b295-c8eab93dc4db',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194037558702104,
#                                                52.18562364361006],
#                                               [0.194035313705211,
#                                                52.18567518740834],
#                                               [0.194090524871573,
#                                                52.185675750137676],
#                                               [0.194093256758973,
#                                                52.1856245716102],
#                                               [0.194037558702104,
#                                                52.18562364361006]]]],
#                             'type': 'MultiPolygon'},
#                'id': 'c04caa38-ee63-4ca1-9a29-87bbc3a0896c',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'level_id': '227dbfdb-5ef2-4a9f-b295-c8eab93dc4db',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194280082778044,
#                                                52.18564576372339],
#                                               [0.194228712842049,
#                                                52.185645578076596],
#                                               [0.194231806940102,
#                                                52.185592702565636],
#                                               [0.194146301708928,
#                                                52.185592190532375],
#                                               [0.194145466162433,
#                                                52.18560019200002],
#                                               [0.194069868924426,
#                                                52.185600196861444],
#                                               [0.194069276858547,
#                                                52.18561340537819],
#                                               [0.194038006551374,
#                                                52.18561336124907],
#                                               [0.194037542934714,
#                                                52.185624005620205],
#                                               [0.194093243803826,
#                                                52.18562493962979],
#                                               [0.194091448879848,
#                                                52.185675928385116],
#                                               [0.194278114472344,
#                                                52.18567761117395],
#                                               [0.194280105317845,
#                                                52.185649897211306],
#                                               [0.194280082778044,
#                                                52.18564576372339]]]],
#                             'type': 'MultiPolygon'},
#                'id': '233465e3-ba67-4633-bc0f-f8275c3af693',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'level_id': '227dbfdb-5ef2-4a9f-b295-c8eab93dc4db',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194282044215818,
#                                                52.18560256340554],
#                                               [0.194231581481576,
#                                                52.18560182450015],
#                                               [0.194229319928131,
#                                                52.18563234144495],
#                                               [0.194280824502974,
#                                                52.185632339939936],
#                                               [0.194282044215818,
#                                                52.18560256340554]]]],
#                             'type': 'MultiPolygon'},
#                'id': '9e1e07ac-5783-438c-9100-b64700f7cf38',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'level_id': '227dbfdb-5ef2-4a9f-b295-c8eab93dc4db',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194280824502974,
#                                                52.185632339939936],
#                                               [0.194229475345016,
#                                                52.18563254755354],
#                                               [0.194228723523121,
#                                                52.185645395546224],
#                                               [0.194280082778044,
#                                                52.18564576372339],
#                                               [0.194280824502974,
#                                                52.185632339939936]]]],
#                             'type': 'MultiPolygon'},
#                'id': '4637c2bc-1509-48df-999f-1f2432d0fc60',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'level_id': '227dbfdb-5ef2-4a9f-b295-c8eab93dc4db',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194215184041022,
#                                                52.1856770438566],
#                                               [0.194213813484216,
#                                                52.185720196788864],
#                                               [0.194275632322694,
#                                                52.185720930519864],
#                                               [0.19427769090413,
#                                                52.18567760735549],
#                                               [0.194215184041022,
#                                                52.1856770438566]]]],
#                             'type': 'MultiPolygon'},
#                'id': '5dc1f254-3fb9-4bac-b6fe-085c5b7622a8',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'level_id': '227dbfdb-5ef2-4a9f-b295-c8eab93dc4db',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194212446175943,
#                                                52.18575798167583],
#                                               [0.194215870211955,
#                                                52.18567705004243],
#                                               [0.194035313705211,
#                                                52.18567518740834],
#                                               [0.194029595177981,
#                                                52.18585976553365],
#                                               [0.194207676623847,
#                                                52.185860996401026],
#                                               [0.194212446175943,
#                                                52.18575798167583]]]],
#                             'type': 'MultiPolygon'},
#                'id': '1261d53f-cf96-4555-9aee-a29cbc2cf7fa',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'level_id': '227dbfdb-5ef2-4a9f-b295-c8eab93dc4db',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194273196558402,
#                                                52.185720901609656],
#                                               [0.19421503467053,
#                                                52.18572021128318],
#                                               [0.194211904022436,
#                                                52.1857696913397],
#                                               [0.194316439580315,
#                                                52.185769507102904],
#                                               [0.19431815118131,
#                                                52.185721119240256],
#                                               [0.194273196558402,
#                                                52.185720901609656]]]],
#                             'type': 'MultiPolygon'},
#                'id': 'ce281d2d-06bc-4378-9e7b-0cc5e042bbdb',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'level_id': '227dbfdb-5ef2-4a9f-b295-c8eab93dc4db',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194209384620221,
#                                                52.18582410642839],
#                                               [0.194314049489127,
#                                                52.18582505527282],
#                                               [0.194316439580315,
#                                                52.185769507102904],
#                                               [0.194211904022436,
#                                                52.1857696913397],
#                                               [0.194209384620221,
#                                                52.18582410642839]]]],
#                             'type': 'MultiPolygon'},
#                'id': 'efb1bccb-ab7f-4d59-b47c-eda691e2ff6f',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'level_id': '227dbfdb-5ef2-4a9f-b295-c8eab93dc4db',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194280031590874,
#                                                52.18565092354265],
#                                               [0.194276713694786,
#                                                52.18572044199834],
#                                               [0.19431815118131,
#                                                52.185721119240256],
#                                               [0.194314049489127,
#                                                52.18582505527282],
#                                               [0.194383899113887,
#                                                52.18582526603955],
#                                               [0.194385761533136,
#                                                52.18574308845524],
#                                               [0.194386786050685,
#                                                52.18572267547197],
#                                               [0.194433181781559,
#                                                52.18572268045688],
#                                               [0.194436521544227,
#                                                52.185651650402505],
#                                               [0.194280031590874,
#                                                52.18565092354265]]]],
#                             'type': 'MultiPolygon'},
#                'id': '5b344a0e-0b13-40fa-8521-8342594e4f94',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'level_id': '227dbfdb-5ef2-4a9f-b295-c8eab93dc4db',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194385448646284,
#                                                52.18577020168093],
#                                               [0.194383899113887,
#                                                52.18582526603955],
#                                               [0.194482060563663,
#                                                52.18582484590698],
#                                               [0.194482904491888,
#                                                52.185769125857206],
#                                               [0.194385448646284,
#                                                52.18577020168093]]]],
#                             'type': 'MultiPolygon'},
#                'id': 'cc64961d-0696-407a-bc26-842d23ab3680',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'level_id': '227dbfdb-5ef2-4a9f-b295-c8eab93dc4db',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194435152390625,
#                                                52.18568076956763],
#                                               [0.194671134371609,
#                                                52.185683304820614],
#                                               [0.194676646319221,
#                                                52.185510821304575],
#                                               [0.19444335018806,
#                                                52.18550651209685],
#                                               [0.194435152390625,
#                                                52.18568076956763]]]],
#                             'type': 'MultiPolygon'},
#                'id': 'd85cc155-2260-43aa-9ed7-8e8bc63c147f',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'level_id': '227dbfdb-5ef2-4a9f-b295-c8eab93dc4db',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194433289351939,
#                                                52.185722479408795],
#                                               [0.194486158394749,
#                                                52.18572225650693],
#                                               [0.19448889863994,
#                                                52.185681346986044],
#                                               [0.194435152390625,
#                                                52.18568076956763],
#                                               [0.194433289351939,
#                                                52.185722479408795]]]],
#                             'type': 'MultiPolygon'},
#                'id': 'b6f05f6c-c91c-4911-82fa-ea04247104dd',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'level_id': '227dbfdb-5ef2-4a9f-b295-c8eab93dc4db',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194482060563663,
#                                                52.18582484590698],
#                                               [0.194477962732577,
#                                                52.18586965018295],
#                                               [0.194664424804332,
#                                                52.18587135135343],
#                                               [0.194670774028302,
#                                                52.1856840520219],
#                                               [0.19448889863994,
#                                                52.185681346986044],
#                                               [0.194482060563663,
#                                                52.18582484590698]]]],
#                             'type': 'MultiPolygon'},
#                'id': '08edb4b2-166d-42ee-a828-7e0118ab8b12',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'level_id': '227dbfdb-5ef2-4a9f-b295-c8eab93dc4db',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194385473298341,
#                                                52.185755806567826],
#                                               [0.194451729437969,
#                                                52.185755808907636],
#                                               [0.194452305695465,
#                                                52.18573496387985],
#                                               [0.194386152005264,
#                                                52.18573530850078],
#                                               [0.194385473298341,
#                                                52.185755806567826]]]],
#                             'type': 'MultiPolygon'},
#                'id': 'd2f0397c-c549-4ff1-904e-0f063f1dd222',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'level_id': '227dbfdb-5ef2-4a9f-b295-c8eab93dc4db',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194386158171574,
#                                                52.18573518564023],
#                                               [0.194386686662252,
#                                                52.18573530571554],
#                                               [0.194452305695465,
#                                                52.18573496387985],
#                                               [0.194451739140179,
#                                                52.18575545794858],
#                                               [0.194385473298341,
#                                                52.185755806567826],
#                                               [0.194385448646284,
#                                                52.18577020168093],
#                                               [0.194484723148748,
#                                                52.18576897087801],
#                                               [0.194486943329242,
#                                                52.18572237976883],
#                                               [0.194386781176728,
#                                                52.18572277258305],
#                                               [0.194386158171574,
#                                                52.18573518564023]]]],
#                             'type': 'MultiPolygon'},
#                'id': '9476bfa3-048e-4ad0-a95d-f2a7e98b476b',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'level_id': '227dbfdb-5ef2-4a9f-b295-c8eab93dc4db',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194031141484023,
#                                                52.185859776221434],
#                                               [0.194024915584942,
#                                                52.186008239556855],
#                                               [0.194233501496838,
#                                                52.186011913928326],
#                                               [0.194236574870153,
#                                                52.185937484608424],
#                                               [0.194439417508953,
#                                                52.18594031104058],
#                                               [0.194437390422646,
#                                                52.186027193533775],
#                                               [0.194659826680337,
#                                                52.18602891816133],
#                                               [0.194664424804332,
#                                                52.18587135135343],
#                                               [0.194477962732577,
#                                                52.18586965018295],
#                                               [0.194480610003837,
#                                                52.18582485211539],
#                                               [0.194209349142443,
#                                                52.18582487269158],
#                                               [0.194207676623847,
#                                                52.185860996401026],
#                                               [0.194031141484023,
#                                                52.185859776221434]]]],
#                             'type': 'MultiPolygon'},
#                'id': 'c301f7fc-03e6-4bb8-9ab1-a649b5c0cd6e',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'level_id': '227dbfdb-5ef2-4a9f-b295-c8eab93dc4db',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'}],
#  'name': 'unit',
#  'type': 'FeatureCollection'}

# %%
## Transform opening.geojson by setting its display point as the centre of the line

import json

def compute_line_center(coordinates):
    """
    Compute the center of a line given its coordinates.
    """
    x_coords = [coord[0] for coord in coordinates[0]]
    y_coords = [coord[1] for coord in coordinates[0]]
    
    return [sum(x_coords) / len(x_coords), sum(y_coords) / len(y_coords)]

def update_openings():
    """
    Update the display_point and category for each opening.
    """


    for opening in opening_structure['features']:
        center = compute_line_center(opening['geometry']['coordinates'])
        opening['properties']['display_point'] = {
            "coordinates": center,
            "type": "Point"
        }
        opening['properties']['category'] = "pedestrian"

# Sample usage:
update_openings()

# %%
## generate occupant.geojson that references the UUID

import json
import os
import uuid


# Generate features for the occupant.geojson
for feature in anchor_structure["features"]:
    occupant_feature = {
        "geometry": None,
        "feature_type": "occupant",
        "id": str(uuid.uuid4()),  
        "properties": {
            "alt_name": None,
            "category": None,
            "hours": "",
            "name": {
                "en": "Test"
            },
            "anchor_id": feature["id"],
            "phone": "",
            "restriction": None,
            "website": None,
            "correlation_id": None
        },
        "type": "Feature"
    }
    occupant_structure["features"].append(occupant_feature)

 # Remove the sample feature
occupant_structure["features"].pop(0)

from pprint import pprint
pprint(occupant_structure)
# Out:
# {'features': [{'feature_type': 'occupant',
#                'geometry': None,
#                'id': '6c7613a8-d4b5-4a5c-bc09-bc9f56ce3a26',
#                'properties': {'alt_name': None,
#                               'anchor_id': '34f0d545-4646-4470-8e1a-a4ad7c15a031',
#                               'category': None,
#                               'correlation_id': None,
#                               'hours': '',
#                               'name': {'en': 'Test'},
#                               'phone': '',
#                               'restriction': None,
#                               'website': None},
#                'type': 'Feature'},
#               {'feature_type': 'occupant',
#                'geometry': None,
#                'id': 'c9e982e8-4df7-45be-b0ca-4f6ec6ad600a',
#                'properties': {'alt_name': None,
#                               'anchor_id': '0215c4a4-2fa1-469b-8cc9-4c5994684694',
#                               'category': None,
#                               'correlation_id': None,
#                               'hours': '',
#                               'name': {'en': 'Test'},
#                               'phone': '',
#                               'restriction': None,
#                               'website': None},
#                'type': 'Feature'},
#               {'feature_type': 'occupant',
#                'geometry': None,
#                'id': '760232b5-0213-463c-a74a-f410bf419060',
#                'properties': {'alt_name': None,
#                               'anchor_id': '9368774d-ac79-4219-996e-379af0b2a95f',
#                               'category': None,
#                               'correlation_id': None,
#                               'hours': '',
#                               'name': {'en': 'Test'},
#                               'phone': '',
#                               'restriction': None,
#                               'website': None},
#                'type': 'Feature'},
#               {'feature_type': 'occupant',
#                'geometry': None,
#                'id': '86e5785a-370b-4db5-b966-27f0080a9e95',
#                'properties': {'alt_name': None,
#                               'anchor_id': '5bf69137-409b-44f2-b1e8-2ad71c006162',
#                               'category': None,
#                               'correlation_id': None,
#                               'hours': '',
#                               'name': {'en': 'Test'},
#                               'phone': '',
#                               'restriction': None,
#                               'website': None},
#                'type': 'Feature'}],
#  'name': 'occupant',
#  'type': 'FeatureCollection'}

# %%
import json
import os

# List of your 10 structures (dictionaries)
structures = [address_structure, amenity_structure, anchor_structure, building_structure, footprint_structure, level_structure, occupant_structure, opening_structure, unit_structure, venue_structure]

# Specify the base directory where you want to save the GeoJSON files
base_directory = "C:\\Users\\amosk\\GitHub\\Geojson_2_IMDF_Transformer\\CPC4_Transformed_Geojsons"

# Loop through the structures and save each one to a separate GeoJSON file
for structure_name, structure in zip(["address", "amenity", "anchor", "building", "footprint", "level", "occupant", "opening", "unit", "venue"], structures):
    # Generate the file name
    geojson_file_name = f"{structure_name}.geojson"
    
    # Construct the full file path
    file_path = os.path.join(base_directory, geojson_file_name)
    
    # Save the structure to the GeoJSON file
    with open(file_path, "w") as geojson_file:
        json.dump(structure, geojson_file, indent=2)
