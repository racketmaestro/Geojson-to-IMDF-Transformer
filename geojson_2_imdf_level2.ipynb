# %%
## initialize dictionaries with some predefined values

address_structure = {
    "type": "FeatureCollection",
    "name": "address",
    "features": [
        {
            "geometry": None,
            "feature_type":"address",
            "id": "3c8510c2-4793-4204-9b26-0844ad4c0af4",
            "properties": {
                "address": "CPC4, Capital Park, Fulbourn, Cambridge",
                "country": "GB",
                "locality": "Cambridge",
                "postal_code": "CB21 5XE",
                "postal_code_ext": None,
                "province": "GB-CAM",
                "unit": None
            },
            "type": "Feature"
        }
    ]
}

amenity2_structure = {
    "type": "FeatureCollection",
   "name": "amenity",
    "features": [
        {
            "geometry": {
                "type": "Point",
                "coordinates": []
            },
            "type": "Feature",
            "feature_type":"amenity",
            "id": "",
            "properties": {
                "accessibility": None,
                "address_id": "",
                "alt_name": None,
                "category": "restroom",
                "correlation_id": None,
                "hours": None,
                "name": None,
                "phone": None,
                "unit_ids": [],
                "website": None
            }
        }
    ]
}

anchor2_structure = {
    "type": "FeatureCollection",
   "name": "anchor",
    "features": [
        {
            "geometry": {
                "type": "Point",
                "coordinates": []
            },
            "feature_type":"anchor",
            "id": "",
            "properties": {
                "address_id": "",
                "unit_id": ""
            },
            "type": "Feature"
        }
    ]
}

building_structure = {
    "type": "FeatureCollection",
   "name": "building",
        "features": [
        {
            "geometry": None,
            "feature_type":"building",
            "id": "8d13e6e3-b5d2-4351-832e-7204aa2bb65e",
            "properties": {
                "address_id": "",
                "alt_name": None,
                "category": "unspecified",
                "display_point": {
                    "coordinates": [0.19458723822821,
                    52.185771666941406],
                    "type":"Point"
                },
                "name": {
                    "en": "CPC4"
                },
                "restriction": None
            },
            "type": "Feature"
        }
    ]
}

footprint_structure = {
    "type": "FeatureCollection",
    "name": "footprint",
     "features": [
        {
            "geometry": {
                "type": "MultiPolygon",
                "coordinates": []
            },
            "feature_type":"footprint",
            "id": "",
            "properties": {
                "building_ids": [],
                "category": "ground",
                "name": None
            },
            "type": "Feature"
        }
    ]
}

level2_structure = {
    "type": "FeatureCollection",
   "name": "level",
    "features": [
        {
            "geometry": {
                "type": "MultiPolygon",
                "coordinates": []
            },
            "feature_type":"level",
            "id": "",
            "properties": {
                "address_id": "",
                "building_ids": [],
                "category": "unspecified",
                "display_point": {
                    "coordinates": [0.19458723822821,
                                52.185771666941406],
                    "type":"Point"
                },
                "name": {
                    "en": "First Floor"
                },
                "ordinal": 1,
                "outdoor": False,
                "restriction": None,
                "short_name": {
                    "en": "1"
                }
            },
            "type": "Feature"
        }
    ]
}

occupant2_structure = {
    "type": "FeatureCollection",
   "name": "occupant",
    "features": [
        {
            "geometry": None,
            "feature_type": "occupant",
            "id": "",
            "properties": {
                "alt_name": None,
                "anchor_id": "",
                "category": "",
                "hours": "",
                "name": {
                    "en": ""
                },
                "phone": "",
                "restriction": None,
                "website": None,
                "correlation_id": None
            },
            "type": "Feature"
        }
    ]
}

opening2_structure = {
    "type": "FeatureCollection",
   "name": "opening",
    "features": [
        {
            "geometry": {
                "type": "MultiLineString",
                "coordinates": []
            },
            "type":"Feature",
            "feature_type": "opening",
            "id": "",
            "properties": {
                "access_control": None,
                "accessibility": None,
                "alt_name": None,
                "category": "",
                "display_point": {
                    "coordinates": [],
                    "type":"Feature"
                },
                "door": None,
                "level_id": "",
                "name": None
            }
        }
    ]
}


unit2_structure = {
    "type": "FeatureCollection",
   "name": "unit",
    "features": [
        {
            "geometry": {
                "type": "MultiPolygon",
                "coordinates": []
            }, 
            "type":"Feature",
            "feature_type": "unit",
            "id": "",
            "properties": {
                "accessibility": None,
                "alt_name": None,
                "category": "office",
                "level_id": "",
                "name": None,
                "restriction": None
            }
        }
    ]
}

venue_structure = {
    "type": "FeatureCollection",
   "name": "venue",
    "features": [
        {
            "geometry": {
                "type": "MultiPolygon",
                "coordinates": []
            },
            "feature_type":"venue",
            "id":"bff9670a-db54-4383-b9f0-3be4d25c70e3",
            "properties": {
                "address_id": "",
                "alt_name": None,
                "category": "businesscampus",
                "display_point": {
                    "coordinates": [0.19458723822821,
                                    52.185771666941406],
                    "type":"Point"
                },
                "hours": "",
                "name": {
                    "en": "CPC4"
                },
                "phone": None,
                "restriction": None,
                "website": ""
            },
            "type":"Feature"
        }
    ]
}

# %%
import os
import json

## Copy the coordinates over
# Your folder path
folder_path = "C:\\Users\\amosk\\GitHub\\Geojson_2_IMDF_Transformer\\HDI_QGIS_Geojsons"

# Map each structure to its name
structures = {
    "address": address_structure,
    "amenity2": amenity2_structure,
    "anchor2": anchor2_structure,
    "building": building_structure,
    "footprint": footprint_structure,
    "level2": level2_structure,
    "occupant2": occupant2_structure,
    "opening2": opening2_structure,
    "unit2": unit2_structure,
    "venue": venue_structure,
}

# Iterate through the files in your folder
for file_name in os.listdir(folder_path):
    # Check if the file has the .geojson extension
    if not file_name.endswith('.geojson'):
        continue

    # Extract feature type from the file name
    feature_type = file_name.split('.')[0]
    
    # If the structure doesn't exist for this file, skip it
    if feature_type not in structures:
        print(f"No structure found for {feature_type}. Skipping...")
        continue
    
    # Read the geojson file
    with open(os.path.join(folder_path, file_name), 'r') as file:
        geojson_data = json.load(file)

    # Iterate through features in the geojson file
    for feature in geojson_data.get("features", []):
        # Create a new feature based on the sample structure
        new_feature = structures[feature_type]["features"][0].copy()
        
        # Preserve existing properties in the sample structure
        for key in new_feature["properties"]:
            if key not in feature["properties"]:
                continue
            new_feature["properties"][key] = feature["properties"][key]
        
        # Copy geometry from the geojson feature
        new_feature["geometry"] = feature["geometry"]
        
        # Append the new feature to the structure
        structures[feature_type]["features"].append(new_feature)

    # Remove the sample feature
    structures[feature_type]["features"].pop(0)


from pprint import pprint
# pprint(footprint_structure)
# Out:
# No structure found for amenity. Skipping...
# No structure found for anchor. Skipping...
# No structure found for level. Skipping...
# No structure found for opening. Skipping...
# No structure found for unit. Skipping...

# %%
## add UUID

import uuid

def generate_uuid_for_structures(structures):
    for structure in structures.values():
        for feature in structure['features']:
            feature['id'] = str(uuid.uuid4())
    return structures

# Map each structure to its name
structures = {
    "amenity2": amenity2_structure,
    "anchor2": anchor2_structure,
    "level2": level2_structure,
    "occupant2": occupant2_structure,
    "opening2": opening2_structure,
    "unit2": unit2_structure,
}

structures = generate_uuid_for_structures(structures)

# %%
import json

# Extract UUID from the given structure based on the feature type.
def get_uuid_from_structure(structure, feature_type):
    for feature in structure.get('features', []):
        if feature.get('feature_type') == feature_type:
            return feature.get('id')
    return None

# Update the address_id, building_ids, and level_id in the given structure with the provided UUIDs.
def update_ids_in_structure(structure, address_uuid, building_uuid, level_uuid):
    for feature in structure.get('features', []):
        # Only replace the keys if they already exist in the properties
        if 'address_id' in feature['properties']:
            feature['properties']['address_id'] = address_uuid
        if 'building_ids' in feature['properties']:
            feature['properties']['building_ids'] = [building_uuid]
        if 'level_id' in feature['properties']:
            feature['properties']['level_id'] = level_uuid

def main():
    # Extract UUIDs from address, building, and level structures
    address_uuid = get_uuid_from_structure(address_structure, 'address')
    building_uuid = get_uuid_from_structure(building_structure, 'building')
    level_uuid = get_uuid_from_structure(level2_structure, 'level')

    # List of structures that need to be updated
    structures_to_update = [level2_structure, opening2_structure, unit2_structure, 
                            anchor2_structure, amenity2_structure]

    for struct in structures_to_update:
        update_ids_in_structure(struct, address_uuid, building_uuid, level_uuid)
        print(f"Updated IDs in {struct['features'][0]['feature_type']} structure")

main()


# pprint(unit_structure)
# print(footprint_structure)
# Out:
# Updated IDs in level structure
# Updated IDs in opening structure
# Updated IDs in unit structure
# Updated IDs in anchor structure
# Updated IDs in amenity structure

# %%
# Ray-casting algorithm to determine if a point is inside a polygon
def is_point_inside_polygon(point, polygon):
    x, y = point
    oddNodes = False
    j = len(polygon) - 1

    for i in range(len(polygon)):
        xi, yi = polygon[i]
        xj, yj = polygon[j]
        if yi < y and yj >= y or yj < y and yi >= y:
            if xi + (y - yi) / (yj - yi) * (xj - xi) < x:
                oddNodes = not oddNodes
        j = i
    return oddNodes

anchor_structure_new = {'features' : []}
amenity_structure_new = {'features' : []}

import copy

for anchor_feature in anchor2_structure['features']:
    point = tuple(anchor_feature['geometry']['coordinates'])

    for unit_feature in unit2_structure['features']:
        polygon = unit_feature['geometry']['coordinates'][0][0]
        if is_point_inside_polygon(point, polygon):
            new_anchor_feature = copy.deepcopy(anchor_feature)  # Create a deep copy
            new_anchor_feature['properties']['unit_id'] = unit_feature['id']
            anchor_structure_new['features'].append(new_anchor_feature)
            break


for amenity_feature in amenity2_structure['features']:
    point = tuple(amenity_feature['geometry']['coordinates'])

    for unit_feature in unit2_structure['features']:
        polygon = unit_feature['geometry']['coordinates'][0][0]
        if is_point_inside_polygon(point, polygon):
            new_amenity_feature = copy.deepcopy(amenity_feature)  # Create a deep copy
            new_amenity_feature['properties']['unit_ids'] = [unit_feature['id']]
            amenity_structure_new['features'].append(new_amenity_feature)
            break

# %%
anchor2_structure = anchor_structure_new
anchor2_structure["type"] = "FeatureCollection"
anchor2_structure["name"] = "anchor"
pprint(anchor2_structure)

amenity2_structure = amenity_structure_new
amenity2_structure["type"] = "FeatureCollection"
amenity2_structure["name"] = "amenity"
pprint(amenity2_structure)
# Out:
# {'features': [{'feature_type': 'anchor',
#                'geometry': {'coordinates': [0.194122326246511,
#                                             52.185771707651135],
#                             'type': 'Point'},
#                'id': '30029977-2e14-4b6d-962c-de436cea30f3',
#                'properties': {'address_id': '3c8510c2-4793-4204-9b26-0844ad4c0af4',
#                               'unit_id': '9a6e4020-497e-4bf0-b703-2e231da961e5'},
#                'type': 'Feature'},
#               {'feature_type': 'anchor',
#                'geometry': {'coordinates': [0.194152291636331,
#                                             52.18562614561012],
#                             'type': 'Point'},
#                'id': '351b939b-d0e3-45bc-bdaa-c56a671dc09d',
#                'properties': {'address_id': '3c8510c2-4793-4204-9b26-0844ad4c0af4',
#                               'unit_id': '38e4aa40-46a7-491e-8d30-5e4372734555'},
#                'type': 'Feature'},
#               {'feature_type': 'anchor',
#                'geometry': {'coordinates': [0.194575264638789,
#                                             52.185785133252274],
#                             'type': 'Point'},
#                'id': '81a87751-3d82-4749-8be0-ed7a9e603c5b',
#                'properties': {'address_id': '3c8510c2-4793-4204-9b26-0844ad4c0af4',
#                               'unit_id': 'a32f2fe2-b977-43d2-9072-db10edc7e04f'},
#                'type': 'Feature'},
#               {'feature_type': 'anchor',
#                'geometry': {'coordinates': [0.194557976913893,
#                                             52.18560141414804],
#                             'type': 'Point'},
#                'id': 'f0a8b70a-8ade-4cec-a7cc-090503547124',
#                'properties': {'address_id': '3c8510c2-4793-4204-9b26-0844ad4c0af4',
#                               'unit_id': '3eb9cc6c-bd4f-4385-bc97-9ecada4b9b46'},
#                'type': 'Feature'},
#               {'feature_type': 'anchor',
#                'geometry': {'coordinates': [0.194321711340313,
#                                             52.18589819078529],
#                             'type': 'Point'},
#                'id': '78de626b-9c85-48db-be03-0e0e6d65072f',
#                'properties': {'address_id': '3c8510c2-4793-4204-9b26-0844ad4c0af4',
#                               'unit_id': 'd057f40f-75a9-418d-b232-0188a6275b02'},
#                'type': 'Feature'}],
#  'name': 'anchor',
#  'type': 'FeatureCollection'}
# {'features': [{'feature_type': 'amenity',
#                'geometry': {'coordinates': [0.194469809516923,
#                                             52.185746269658914],
#                             'type': 'Point'},
#                'id': 'f95c9631-ba6a-438d-a71b-dcca3d2d87f8',
#                'properties': {'accessibility': None,
#                               'address_id': '3c8510c2-4793-4204-9b26-0844ad4c0af4',
#                               'alt_name': None,
#                               'category': 'restroom',
#                               'correlation_id': None,
#                               'hours': None,
#                               'name': None,
#                               'phone': None,
#                               'unit_ids': ['cbedf5d2-8b02-4010-8776-1e23c098ded1'],
#                               'website': None},
#                'type': 'Feature'},
#               {'feature_type': 'amenity',
#                'geometry': {'coordinates': [0.194257746758197,
#                                             52.185796085713356],
#                             'type': 'Point'},
#                'id': '335b5351-0f83-4c10-b121-3122902bf587',
#                'properties': {'accessibility': None,
#                               'address_id': '3c8510c2-4793-4204-9b26-0844ad4c0af4',
#                               'alt_name': None,
#                               'category': 'restroom',
#                               'correlation_id': None,
#                               'hours': None,
#                               'name': None,
#                               'phone': None,
#                               'unit_ids': ['17932f8d-0964-49ef-baf9-411be15197a4'],
#                               'website': None},
#                'type': 'Feature'},
#               {'feature_type': 'amenity',
#                'geometry': {'coordinates': [0.194428318977172,
#                                             52.185799618764754],
#                             'type': 'Point'},
#                'id': 'b0522ce7-fa16-47f3-8311-e52a6c7a57f1',
#                'properties': {'accessibility': None,
#                               'address_id': '3c8510c2-4793-4204-9b26-0844ad4c0af4',
#                               'alt_name': None,
#                               'category': 'restroom',
#                               'correlation_id': None,
#                               'hours': None,
#                               'name': None,
#                               'phone': None,
#                               'unit_ids': ['1142650e-d2d8-41c0-9db8-72aab8ee3809'],
#                               'website': None},
#                'type': 'Feature'},
#               {'feature_type': 'amenity',
#                'geometry': {'coordinates': [0.194416217569745,
#                                             52.18574609300614],
#                             'type': 'Point'},
#                'id': '5f3cdcef-007c-4a6c-8323-84f6eab0f4f1',
#                'properties': {'accessibility': None,
#                               'address_id': '3c8510c2-4793-4204-9b26-0844ad4c0af4',
#                               'alt_name': None,
#                               'category': 'restroom',
#                               'correlation_id': None,
#                               'hours': None,
#                               'name': None,
#                               'phone': None,
#                               'unit_ids': ['9968b4b9-eec0-4b91-85ce-e5c81a9816e6'],
#                               'website': None},
#                'type': 'Feature'}],
#  'name': 'amenity',
#  'type': 'FeatureCollection'}

# %%
import json


def compute_polygon_centroid(polygon):
    """
    Compute the centroid of a polygon.
    """
    area = 0.0
    x_centroid = 0.0
    y_centroid = 0.0
    
    for i in range(-1, len(polygon)-1):
        xi, yi = polygon[i]
        xi1, yi1 = polygon[i+1]
        
        fi = xi * yi1 - xi1 * yi
        area += fi
        x_centroid += (xi + xi1) * fi
        y_centroid += (yi + yi1) * fi
    
    area /= 2.0
    x_centroid /= (6.0 * area)
    y_centroid /= (6.0 * area)
    
    return [x_centroid, y_centroid]


# def update_unit_display_point():
#     """
#     Update the display_point for each unit with the centroid of the unit polygon.
#     """

#     for unit in unit_structure['features']:
#         polygon = unit['geometry']['coordinates'][0][0]
#         centroid = compute_polygon_centroid(polygon)
        
#         unit['properties']['display_point'] = {
#             "coordinates": centroid,
#             "type": "Point"
#         }

# update_unit_display_point()
# Iterate through each feature and update the "name" property
for feature in unit2_structure["features"]:
    feature["properties"]["name"] = {"en": "input name here"}
pprint(unit2_structure)
# Out:
# {'features': [{'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194278693956703,
#                                                52.18567895043159],
#                                               [0.194215818903391,
#                                                52.18567826278947],
#                                               [0.194213813484216,
#                                                52.185720196788864],
#                                               [0.194275632322694,
#                                                52.18572093051986],
#                                               [0.194278693956703,
#                                                52.18567895043159]]]],
#                             'type': 'MultiPolygon'},
#                'id': '705b7530-f436-4c3f-8b9c-15196fd6b139',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'level_id': '91ced8d9-7dc0-40fd-b649-8243a8b1b8a3',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.19404495806019,
#                                                52.185675285706594],
#                                               [0.194276617703014,
#                                                52.18567892772434],
#                                               [0.19428319862849,
#                                                52.18557438100898],
#                                               [0.194038717222795,
#                                                52.185570340074925],
#                                               [0.194036883107076,
#                                                52.185675203404166],
#                                               [0.19404495806019,
#                                                52.185675285706594]]]],
#                             'type': 'MultiPolygon'},
#                'id': '38e4aa40-46a7-491e-8d30-5e4372734555',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'level_id': '91ced8d9-7dc0-40fd-b649-8243a8b1b8a3',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194031141484023,
#                                                52.185859776221434],
#                                               [0.194207676623847,
#                                                52.185860996401026],
#                                               [0.194215818903391,
#                                                52.18567826278947],
#                                               [0.194036883107076,
#                                                52.185675203404166],
#                                               [0.194031141484023,
#                                                52.185859776221434]]]],
#                             'type': 'MultiPolygon'},
#                'id': '9a6e4020-497e-4bf0-b703-2e231da961e5',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'level_id': '91ced8d9-7dc0-40fd-b649-8243a8b1b8a3',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194278693956703,
#                                                52.18567895043159],
#                                               [0.194275632322694,
#                                                52.18572093051986],
#                                               [0.19431815118131,
#                                                52.185721119240256],
#                                               [0.194314087823802,
#                                                52.18582416433621],
#                                               [0.194383923740776,
#                                                52.1858241794011],
#                                               [0.194387404694918,
#                                                52.185723216465846],
#                                               [0.194433649362968,
#                                                52.185723217250626],
#                                               [0.194436242729847,
#                                                52.18568108624204],
#                                               [0.194278693956703,
#                                                52.18567895043159]]]],
#                             'type': 'MultiPolygon'},
#                'id': 'e8b90c5e-c370-49b4-ab7d-b09ae65d34bb',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'level_id': '91ced8d9-7dc0-40fd-b649-8243a8b1b8a3',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194434225624451,
#                                                52.18572321726041],
#                                               [0.194486903378138,
#                                                52.18572321815436],
#                                               [0.194489851486205,
#                                                52.18568136115775],
#                                               [0.194436251188142,
#                                                52.185680781372476],
#                                               [0.194434225624451,
#                                                52.18572321726041]]]],
#                             'type': 'MultiPolygon'},
#                'id': '5421c8aa-429e-4d8c-8e15-2d53eee8db8b',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'level_id': '91ced8d9-7dc0-40fd-b649-8243a8b1b8a3',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194436251188142,
#                                                52.185680781372476],
#                                               [0.19467453716915,
#                                                52.185683206226216],
#                                               [0.194679423181288,
#                                                52.18550955431119],
#                                               [0.194443280316519,
#                                                52.18550799717262],
#                                               [0.194436251188142,
#                                                52.185680781372476]]]],
#                             'type': 'MultiPolygon'},
#                'id': '3eb9cc6c-bd4f-4385-bc97-9ecada4b9b46',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'level_id': '91ced8d9-7dc0-40fd-b649-8243a8b1b8a3',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194489851486205,
#                                                52.18568136115775],
#                                               [0.194479313452424,
#                                                52.18586966250613],
#                                               [0.194663713606513,
#                                                52.185871344864864],
#                                               [0.194670774028301,
#                                                52.1856840520219],
#                                               [0.194489851486205,
#                                                52.18568136115775]]]],
#                             'type': 'MultiPolygon'},
#                'id': 'a32f2fe2-b977-43d2-9072-db10edc7e04f',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'level_id': '91ced8d9-7dc0-40fd-b649-8243a8b1b8a3',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194385448646284,
#                                                52.18577020168093],
#                                               [0.194484222030008,
#                                                52.18576897709086],
#                                               [0.194486903378138,
#                                                52.18572321815436],
#                                               [0.194387404694918,
#                                                52.185723216465846],
#                                               [0.194386686662252,
#                                                52.18573530571554],
#                                               [0.194452305695465,
#                                                52.18573496387985],
#                                               [0.194451729437969,
#                                                52.185755808907636],
#                                               [0.194385473298341,
#                                                52.185755806567826],
#                                               [0.194385448646284,
#                                                52.18577020168093]]]],
#                             'type': 'MultiPolygon'},
#                'id': 'cbedf5d2-8b02-4010-8776-1e23c098ded1',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'level_id': '91ced8d9-7dc0-40fd-b649-8243a8b1b8a3',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194386540308673,
#                                                52.18575536727581],
#                                               [0.194451084937857,
#                                                52.185755461390286],
#                                               [0.194452293469439,
#                                                52.185735406133404],
#                                               [0.194387692823666,
#                                                52.18573575881757],
#                                               [0.194386540308673,
#                                                52.18575536727581]]]],
#                             'type': 'MultiPolygon'},
#                'id': '9968b4b9-eec0-4b91-85ce-e5c81a9816e6',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'level_id': '91ced8d9-7dc0-40fd-b649-8243a8b1b8a3',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194385099732047,
#                                                52.18582485936021],
#                                               [0.19448184205522,
#                                                52.18582447964188],
#                                               [0.194484921351719,
#                                                52.185769456530835],
#                                               [0.194386809708881,
#                                                52.18577018665603],
#                                               [0.194385099732047,
#                                                52.18582485936021]]]],
#                             'type': 'MultiPolygon'},
#                'id': '1142650e-d2d8-41c0-9db8-72aab8ee3809',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'level_id': '91ced8d9-7dc0-40fd-b649-8243a8b1b8a3',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194209923145334,
#                                                52.18582411131041],
#                                               [0.194313355674827,
#                                                52.185824864802285],
#                                               [0.194316439580315,
#                                                52.185769507102904],
#                                               [0.194212509368571,
#                                                52.185769690272814],
#                                               [0.194209923145334,
#                                                52.18582411131041]]]],
#                             'type': 'MultiPolygon'},
#                'id': '17932f8d-0964-49ef-baf9-411be15197a4',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'level_id': '91ced8d9-7dc0-40fd-b649-8243a8b1b8a3',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194211933361218,
#                                                52.18576922763897],
#                                               [0.194315371309974,
#                                                52.18576950898565],
#                                               [0.19431815118131,
#                                                52.185721119240256],
#                                               [0.19421503467053,
#                                                52.18572021128318],
#                                               [0.194211933361218,
#                                                52.18576922763897]]]],
#                             'type': 'MultiPolygon'},
#                'id': '2bfe34da-4591-4693-aeec-cf01c43b5016',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'level_id': '91ced8d9-7dc0-40fd-b649-8243a8b1b8a3',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'},
#               {'feature_type': 'unit',
#                'geometry': {'coordinates': [[[[0.194024954383007,
#                                                52.186007008574755],
#                                               [0.194231801924625,
#                                                52.18601188398928],
#                                               [0.194236574870153,
#                                                52.185937484608424],
#                                               [0.194439417508953,
#                                                52.18594031104058],
#                                               [0.194437390422646,
#                                                52.186027193533775],
#                                               [0.194657669460794,
#                                                52.18602714668294],
#                                               [0.194663713606513,
#                                                52.185871344864864],
#                                               [0.194479064610551,
#                                                52.18586966023583],
#                                               [0.194481262634667,
#                                                52.18582474758463],
#                                               [0.194210493606326,
#                                                52.185824872604776],
#                                               [0.194207676623847,
#                                                52.185860996401026],
#                                               [0.194031086356477,
#                                                52.185861090799904],
#                                               [0.194024954383007,
#                                                52.186007008574755]]]],
#                             'type': 'MultiPolygon'},
#                'id': 'd057f40f-75a9-418d-b232-0188a6275b02',
#                'properties': {'accessibility': None,
#                               'alt_name': None,
#                               'category': 'office',
#                               'level_id': '91ced8d9-7dc0-40fd-b649-8243a8b1b8a3',
#                               'name': {'en': 'input name here'},
#                               'restriction': None},
#                'type': 'Feature'}],
#  'name': 'unit',
#  'type': 'FeatureCollection'}

# %%
## Transform opening.geojson by setting its display point as the centre of the line

import json

def compute_line_center(coordinates):
    """
    Compute the center of a line given its coordinates.
    """
    x_coords = [coord[0] for coord in coordinates[0]]
    y_coords = [coord[1] for coord in coordinates[0]]
    
    return [sum(x_coords) / len(x_coords), sum(y_coords) / len(y_coords)]

def update_openings():
    """
    Update the display_point and category for each opening.
    """


    for opening in opening2_structure['features']:
        center = compute_line_center(opening['geometry']['coordinates'])
        opening['properties']['display_point'] = {
            "coordinates": center,
            "type": "Point"
        }
        opening['properties']['category'] = "pedestrian"

# Sample usage:
update_openings()

# %%
## generate occupant.geojson that references the UUID

import json
import os
import uuid


# Generate features for the occupant.geojson
for feature in anchor2_structure["features"]:
    occupant_feature = {
        "geometry": None,
        "feature_type": "occupant",
        "id": str(uuid.uuid4()),  
        "properties": {
            "alt_name": None,
            "category": None,
            "hours": "",
            "name": {
                "en": "Test"
            },
            "anchor_id": feature["id"],
            "phone": "",
            "restriction": None,
            "website": None,
            "correlation_id": None
        },
        "type": "Feature"
    }
    occupant2_structure["features"].append(occupant_feature)

 # Remove the sample feature
occupant2_structure["features"].pop(0)

from pprint import pprint
pprint(occupant2_structure)
# Out:
# {'features': [{'feature_type': 'occupant',
#                'geometry': None,
#                'id': '21cb7abf-bb58-4b34-98e7-97f8f323e40e',
#                'properties': {'alt_name': None,
#                               'anchor_id': '30029977-2e14-4b6d-962c-de436cea30f3',
#                               'category': None,
#                               'correlation_id': None,
#                               'hours': '',
#                               'name': {'en': 'Test'},
#                               'phone': '',
#                               'restriction': None,
#                               'website': None},
#                'type': 'Feature'},
#               {'feature_type': 'occupant',
#                'geometry': None,
#                'id': '9caad0d6-1dff-47fc-a25a-526daec12a6b',
#                'properties': {'alt_name': None,
#                               'anchor_id': '351b939b-d0e3-45bc-bdaa-c56a671dc09d',
#                               'category': None,
#                               'correlation_id': None,
#                               'hours': '',
#                               'name': {'en': 'Test'},
#                               'phone': '',
#                               'restriction': None,
#                               'website': None},
#                'type': 'Feature'},
#               {'feature_type': 'occupant',
#                'geometry': None,
#                'id': '851bcb74-c87f-43bc-8bc0-3788fedb426d',
#                'properties': {'alt_name': None,
#                               'anchor_id': '81a87751-3d82-4749-8be0-ed7a9e603c5b',
#                               'category': None,
#                               'correlation_id': None,
#                               'hours': '',
#                               'name': {'en': 'Test'},
#                               'phone': '',
#                               'restriction': None,
#                               'website': None},
#                'type': 'Feature'},
#               {'feature_type': 'occupant',
#                'geometry': None,
#                'id': '513a6fa9-e5ad-4da9-8ac1-0afef5f57690',
#                'properties': {'alt_name': None,
#                               'anchor_id': 'f0a8b70a-8ade-4cec-a7cc-090503547124',
#                               'category': None,
#                               'correlation_id': None,
#                               'hours': '',
#                               'name': {'en': 'Test'},
#                               'phone': '',
#                               'restriction': None,
#                               'website': None},
#                'type': 'Feature'},
#               {'feature_type': 'occupant',
#                'geometry': None,
#                'id': 'e74f983a-14d8-49c9-aef9-112604ad3e46',
#                'properties': {'alt_name': None,
#                               'anchor_id': '78de626b-9c85-48db-be03-0e0e6d65072f',
#                               'category': None,
#                               'correlation_id': None,
#                               'hours': '',
#                               'name': {'en': 'Test'},
#                               'phone': '',
#                               'restriction': None,
#                               'website': None},
#                'type': 'Feature'}],
#  'name': 'occupant',
#  'type': 'FeatureCollection'}

# %%
import json
import os

# List of your 10 structures (dictionaries)
structures = [amenity2_structure, anchor2_structure, level2_structure, occupant2_structure, opening2_structure, unit2_structure]

# Specify the base directory where you want to save the GeoJSON files
base_directory = "C:\\Users\\amosk\\GitHub\\Geojson_2_IMDF_Transformer\\IMDF"

# Loop through the structures and save each one to a separate GeoJSON file
for structure_name, structure in zip(["amenity2", "anchor2",  "level2", "occupant2", "opening2", "unit2"], structures):
    # Generate the file name
    geojson_file_name = f"{structure_name}.geojson"
    
    # Construct the full file path
    file_path = os.path.join(base_directory, geojson_file_name)
    
    # Save the structure to the GeoJSON file
    with open(file_path, "w") as geojson_file:
        json.dump(structure, geojson_file, indent=2)
